# %%
import pandas as pd
import numpy as np

# %%
dfcust=pd.read_csv(r"C:\Users\admin\Desktop\Pandas\arjun srikant pandas\One Hot Encoding\cust_recom.csv")

# %%
dfcust
# Out:
#     age  gender   review education purchased
# 0    30  Female  Average    School        No
# 1    68  Female     Poor        UG        No
# 2    70  Female     Good        PG        No
# 3    72  Female     Good        PG        No
# 4    16  Female  Average        UG        No
# 5    31  Female  Average    School       Yes
# 6    18    Male     Good    School        No
# 7    60  Female     Poor    School       Yes
# 8    65  Female  Average        UG        No
# 9    74    Male     Good        UG       Yes
# 10   98  Female     Good        UG       Yes
# 11   74    Male     Good        UG       Yes
# 12   51    Male     Poor    School        No
# 13   57  Female  Average    School        No
# 14   15    Male     Poor        PG       Yes
# 15   75    Male     Poor        UG        No
# 16   59    Male     Poor        UG       Yes
# 17   22  Female     Poor        UG       Yes
# 18   19    Male     Good    School        No
# 19   97    Male     Poor        PG       Yes
# ...

# %%
dfcust["education"].unique()
# Out:
# array(['School', 'UG', 'PG'], dtype=object)

# %%
dfdummy=pd.get_dummies(dfcust["education"],drop_first=True)

# %%
dfdummy
# Out:
#     School  UG
# 0        1   0
# 1        0   1
# 2        0   0
# 3        0   0
# 4        0   1
# 5        1   0
# 6        1   0
# 7        1   0
# 8        0   1
# 9        0   1
# 10       0   1
# 11       0   1
# 12       1   0
# 13       1   0
# 14       0   0
# 15       0   1
# 16       0   1
# 17       0   1
# 18       1   0
# 19       0   0
# 20       1   0
# 21       0   0
# 22       0   0
# 23       1   0
# 24       0   0
# 25       1   0
# 26       0   0
# 27       0   0
# 28       1   0
# 29       0   1
# 30       0   1
# 31       1   0
# 32       0   1
# 33       0   0
# 34       1   0
# 35       1   0
# 36       0   1
# 37       0   0
# 38       1   0
# 39       0   0
# 40       1   0
# 41       0   0
# 42       0   0
# 43       0   0
# 44       0   1
# 45       0   0
# 46       0   0
# 47       0   0
# 48       0   1
# 49       0   1

# %%
dfencode=pd.concat([dfcust,dfdummy],axis=1)

# %%
dfencode.drop("education",axis=1)
# Out:
#     age  gender   review purchased  School  UG
# 0    30  Female  Average        No       1   0
# 1    68  Female     Poor        No       0   1
# 2    70  Female     Good        No       0   0
# 3    72  Female     Good        No       0   0
# 4    16  Female  Average        No       0   1
# 5    31  Female  Average       Yes       1   0
# 6    18    Male     Good        No       1   0
# 7    60  Female     Poor       Yes       1   0
# 8    65  Female  Average        No       0   1
# 9    74    Male     Good       Yes       0   1
# 10   98  Female     Good       Yes       0   1
# 11   74    Male     Good       Yes       0   1
# 12   51    Male     Poor        No       1   0
# 13   57  Female  Average        No       1   0
# 14   15    Male     Poor       Yes       0   0
# 15   75    Male     Poor        No       0   1
# 16   59    Male     Poor       Yes       0   1
# 17   22  Female     Poor       Yes       0   1
# 18   19    Male     Good        No       1   0
# ...

# %%
dfdummy1=pd.get_dummies(dfcust["review"])

# %%
dfdummy1
# Out:
#     Average  Good  Poor
# 0         1     0     0
# 1         0     0     1
# 2         0     1     0
# 3         0     1     0
# 4         1     0     0
# 5         1     0     0
# 6         0     1     0
# 7         0     0     1
# 8         1     0     0
# 9         0     1     0
# 10        0     1     0
# 11        0     1     0
# 12        0     0     1
# 13        1     0     0
# 14        0     0     1
# 15        0     0     1
# 16        0     0     1
# 17        0     0     1
# 18        0     1     0
# 19        0     0     1
# 20        1     0     0
# 21        1     0     0
# 22        0     0     1
# 23        0     1     0
# 24        1     0     0
# 25        0     1     0
# 26        0     0     1
# 27        0     0     1
# 28        0     0     1
# 29        1     0     0
# 30        1     0     0
# 31        0     0     1
# 32        1     0     0
# 33        0     1     0
# 34        1     0     0
# 35        0     0     1
# 36        0     1     0
# ...

# %%
encode1=pd.concat([dfcust,dfdummy1],axis=1)

# %%
encode1.drop("review",axis=1,inplace=True)

# %%
dfdummy
# Out:
#     School  UG
# 0        1   0
# 1        0   1
# 2        0   0
# 3        0   0
# 4        0   1
# 5        1   0
# 6        1   0
# 7        1   0
# 8        0   1
# 9        0   1
# 10       0   1
# 11       0   1
# 12       1   0
# 13       1   0
# 14       0   0
# 15       0   1
# 16       0   1
# 17       0   1
# 18       1   0
# 19       0   0
# 20       1   0
# 21       0   0
# 22       0   0
# 23       1   0
# 24       0   0
# 25       1   0
# 26       0   0
# 27       0   0
# 28       1   0
# 29       0   1
# 30       0   1
# 31       1   0
# 32       0   1
# 33       0   0
# 34       1   0
# 35       1   0
# 36       0   1
# 37       0   0
# 38       1   0
# 39       0   0
# 40       1   0
# 41       0   0
# 42       0   0
# 43       0   0
# 44       0   1
# 45       0   0
# 46       0   0
# 47       0   0
# 48       0   1
# 49       0   1

# %%
maincust=pd.concat([encode1,dfdummy],axis=1)

# %%
maincust
# Out:
#     age  gender education purchased  Average  Good  Poor  School  UG
# 0    30  Female    School        No        1     0     0       1   0
# 1    68  Female        UG        No        0     0     1       0   1
# 2    70  Female        PG        No        0     1     0       0   0
# 3    72  Female        PG        No        0     1     0       0   0
# 4    16  Female        UG        No        1     0     0       0   1
# 5    31  Female    School       Yes        1     0     0       1   0
# 6    18    Male    School        No        0     1     0       1   0
# 7    60  Female    School       Yes        0     0     1       1   0
# 8    65  Female        UG        No        1     0     0       0   1
# 9    74    Male        UG       Yes        0     1     0       0   1
# 10   98  Female        UG       Yes        0     1     0       0   1
# 11   74    Male        UG       Yes        0     1     0       0   1
# 12   51    Male    School        No        0     0     1       1   0
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder()

# %%
ohe
# Out:
# OneHotEncoder()

# %%
dfcust
# Out:
#     age  gender   review education purchased
# 0    30  Female  Average    School        No
# 1    68  Female     Poor        UG        No
# 2    70  Female     Good        PG        No
# 3    72  Female     Good        PG        No
# 4    16  Female  Average        UG        No
# 5    31  Female  Average    School       Yes
# 6    18    Male     Good    School        No
# 7    60  Female     Poor    School       Yes
# 8    65  Female  Average        UG        No
# 9    74    Male     Good        UG       Yes
# 10   98  Female     Good        UG       Yes
# 11   74    Male     Good        UG       Yes
# 12   51    Male     Poor    School        No
# 13   57  Female  Average    School        No
# 14   15    Male     Poor        PG       Yes
# 15   75    Male     Poor        UG        No
# 16   59    Male     Poor        UG       Yes
# 17   22  Female     Poor        UG       Yes
# 18   19    Male     Good    School        No
# 19   97    Male     Poor        PG       Yes
# ...

# %%
ohe.fit(dfcust[["education"]])
# Out:
# OneHotEncoder()

# %%
ohe.
