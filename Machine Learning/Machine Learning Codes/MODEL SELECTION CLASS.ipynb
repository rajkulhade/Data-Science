# %%
import pandas as pd
import numpy as np

# %%
dfmovie=pd.read_csv(r"C:\Users\admin\Desktop\Pandas\arjun srikant pandas\One Hot Encoding\cust_recom.csv")

# %%
dfmovie
# Out:
#     age  gender   review education purchased
# 0    30  Female  Average    School        No
# 1    68  Female     Poor        UG        No
# 2    70  Female     Good        PG        No
# 3    72  Female     Good        PG        No
# 4    16  Female  Average        UG        No
# 5    31  Female  Average    School       Yes
# 6    18    Male     Good    School        No
# 7    60  Female     Poor    School       Yes
# 8    65  Female  Average        UG        No
# 9    74    Male     Good        UG       Yes
# 10   98  Female     Good        UG       Yes
# 11   74    Male     Good        UG       Yes
# 12   51    Male     Poor    School        No
# 13   57  Female  Average    School        No
# 14   15    Male     Poor        PG       Yes
# 15   75    Male     Poor        UG        No
# 16   59    Male     Poor        UG       Yes
# 17   22  Female     Poor        UG       Yes
# 18   19    Male     Good    School        No
# 19   97    Male     Poor        PG       Yes
# ...

# %%
dfmovie=dfmovie.drop("purchased",axis=1)

# %%
dfmovie.head()
# Out:
#    age  gender   review education
# 0   30  Female  Average    School
# 1   68  Female     Poor        UG
# 2   70  Female     Good        PG
# 3   72  Female     Good        PG
# 4   16  Female  Average        UG

# %%
dfmovie[["age","gender","education"]]
# Out:
#     age  gender education
# 0    30  Female    School
# 1    68  Female        UG
# 2    70  Female        PG
# 3    72  Female        PG
# 4    16  Female        UG
# 5    31  Female    School
# 6    18    Male    School
# 7    60  Female    School
# 8    65  Female        UG
# 9    74    Male        UG
# 10   98  Female        UG
# 11   74    Male        UG
# 12   51    Male    School
# 13   57  Female    School
# 14   15    Male        PG
# 15   75    Male        UG
# 16   59    Male        UG
# 17   22  Female        UG
# 18   19    Male    School
# 19   97    Male        PG
# 20   57  Female    School
# 21   32    Male        PG
# 22   18  Female        PG
# 23   96  Female    School
# 24   16  Female        PG
# 25   57  Female    School
# 26   53  Female        PG
# 27   69  Female        PG
# 28   48    Male    School
# 29   83  Female        UG
# 30   73    Male        UG
# 31   22  Female    School
# 32   92    Male        UG
# 33   89  Female        PG
# ...

# %%
X=dfmovie.drop("review",axis=1)

# %%
y=dfmovie[["review"]]

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.20)

# %%
Xtrain
# Out:
#     age  gender education
# 15   75    Male        UG
# 24   16  Female        PG
# 2    70  Female        PG
# 35   74    Male    School
# 10   98  Female        UG
# 31   22  Female    School
# 25   57  Female    School
# 11   74    Male        UG
# 17   22  Female        UG
# 45   61    Male        PG
# 41   23    Male        PG
# 46   64  Female        PG
# 48   39  Female        UG
# 43   27    Male        PG
# 22   18  Female        PG
# 18   19    Male    School
# 47   38  Female        PG
# 34   86    Male    School
# 0    30  Female    School
# 23   96  Female    School
# 36   34  Female        UG
# 6    18    Male    School
# 13   57  Female    School
# 20   57  Female    School
# 1    68  Female        UG
# 33   89  Female        PG
# 44   77  Female        UG
# 12   51    Male    School
# 21   32    Male        PG
# 7    60  Female    School
# 19   97    Male        PG
# 5    31  Female    School
# 40   39    Male    School
# 3    72  Female        PG
# ...

# %%
ytrain
# Out:
#      review
# 15     Poor
# 24  Average
# 2      Good
# 35     Poor
# 10     Good
# 31     Poor
# 25     Good
# 11     Good
# 17     Poor
# 45     Poor
# 41     Good
# 46     Poor
# 48     Good
# 43     Poor
# 22     Poor
# 18     Good
# 47     Good
# 34  Average
# 0   Average
# 23     Good
# 36     Good
# 6      Good
# 13  Average
# 20  Average
# 1      Poor
# 33     Good
# 44  Average
# 12     Poor
# 21  Average
# 7      Poor
# 19     Poor
# 5   Average
# 40     Good
# 3      Good
# 4   Average
# 29  Average
# 38     Good
# 39     Poor
# 16     Poor
# 37  Average

# %%
Xtrain.head()
# Out:
#     age  gender education
# 15   75    Male        UG
# 24   16  Female        PG
# 2    70  Female        PG
# 35   74    Male    School
# 10   98  Female        UG

# %%
Xtrain.shape
# Out:
# (40, 3)

# %%
y.shape
# Out:
# (50, 1)

# %%
ytrain.shape
# Out:
# (40, 1)

# %%
ytest.shape
# Out:
# (10, 1)
