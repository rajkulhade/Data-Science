# %%
import pandas as  pd
import numpy as np

# %%
df_sonar=pd.read_csv(r"C:\Users\admin\Desktop\DATA SCIENCE\Machine Learning\machine learning dataset\sonar.all-data.csv",header=None)

# %%
df_sonar
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
sonar=pd.get_dummies(df_sonar,drop_first=True)

# %%
sonar
# Out:
#           0       1       2       3       4       5       6       7       8  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
sonar1=sonar.sample(frac=1)

# %%
sonar1
# Out:
#           0       1       2       3       4       5       6       7       8  \
# 28   0.0100  0.0275  0.0190  0.0371  0.0416  0.0201  0.0314  0.0651  0.1896
# 150  0.0209  0.0278  0.0115  0.0445  0.0427  0.0766  0.1458  0.1430  0.1894
# 53   0.0293  0.0378  0.0257  0.0062  0.0130  0.0612  0.0895  0.1107  0.0973
# 148  0.0712  0.0901  0.1276  0.1497  0.1284  0.1165  0.1285  0.1684  0.1830
# 129  0.1371  0.1226  0.1385  0.1484  0.1776  0.1428  0.1773  0.2161  0.1630
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 127  0.0209  0.0261  0.0120  0.0768  0.1064  0.1680  0.3016  0.3460  0.3314
# 131  0.1150  0.1163  0.0866  0.0358  0.0232  0.1267  0.2417  0.2661  0.4346
# 145  0.0721  0.1574  0.1112  0.1085  0.0666  0.1800  0.1108  0.2794  0.1408
# 158  0.0107  0.0453  0.0289  0.0713  0.1075  0.1019  0.1606  0.2119  0.3061
# 159  0.0235  0.0220  0.0167  0.0516  0.0746  0.1121  0.1258  0.1717  0.3074
#
# ...

# %%
sonar2=sonar1.sample(208)

# %%
sonar2
# Out:
#           0       1       2       3       4       5       6       7       8  \
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
# 112  0.0454  0.0472  0.0697  0.1021  0.1397  0.1493  0.1487  0.0771  0.1171
# 201  0.0335  0.0258  0.0398  0.0570  0.0529  0.1091  0.1709  0.1684  0.1865
# 61   0.0135  0.0045  0.0051  0.0289  0.0561  0.0929  0.1031  0.0883  0.1596
# 22   0.0099  0.0484  0.0299  0.0297  0.0652  0.1077  0.2363  0.2385  0.0075
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 200  0.0131  0.0387  0.0329  0.0078  0.0721  0.1341  0.1626  0.1902  0.2610
# 194  0.0392  0.0108  0.0267  0.0257  0.0410  0.0491  0.1053  0.1690  0.2105
# 10   0.0039  0.0063  0.0152  0.0336  0.0310  0.0284  0.0396  0.0272  0.0323
# 20   0.0473  0.0509  0.0819  0.1252  0.1783  0.3070  0.3008  0.2362  0.3830
# 79   0.0108  0.0086  0.0058  0.0460  0.0752  0.0887  0.1015  0.0494  0.0472
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
rfc=RandomForestClassifier()

# %%
dtc=DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split

# %%
X=sonar2.drop("60_R",axis=1)

# %%
y=sonar2["60_R"]

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.20)

# %%
Xtrain.shape,Xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((166, 60), (42, 60), (166,), (42,))

# %%
rfc.fit(Xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
rfc.score(Xtrain,ytrain)
# Out:
# 1.0

# %%
rfc.score(Xtest,ytest)
# Out:
# 0.8333333333333334

# %%
dtc.fit(Xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(Xtest,ytest)
# Out:
# 0.6904761904761905

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
abc=AdaBoostClassifier(n_estimators=100)

# %%
abc.fit(Xtrain,ytrain)
# Out:
# AdaBoostClassifier(n_estimators=100)

# %%
abc.score(Xtest,ytest)
# Out:
# 0.7619047619047619

# %%
from sklearn.linear_model import LogisticRegression

# %%
lreg=LogisticRegression()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc1=DecisionTreeClassifier()

# %%
from sklearn.svm import SVC

# %%
svm=SVC()

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc1=RandomForestClassifier()

# %%
algo=[lreg,lr,knn,svm,rfc1,dtc1]

# %%
from sklearn.model_selection import cross_val_score,KFold

# %%
kf=KFold(n_splits=10)

# %%
for m in algo:
    res=cross_val_score(m,X,y,cv=kf)
    print("score of ",m,"is",res.mean())
# Out:
# score of  LogisticRegression() is 0.7933333333333333
# score of  LinearRegression() is -0.004011821786875924
# score of  KNeighborsClassifier() is 0.8216666666666667
# score of  SVC() is 0.812857142857143
# score of  RandomForestClassifier() is 0.8319047619047619
# score of  DecisionTreeClassifier() is 0.7066666666666666

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bg=BaggingClassifier()

# %%
bg.fit(Xtrain,ytrain)
# Out:
# BaggingClassifier()

# %%
bg.score(Xtest,ytest)
# Out:
# 0.7380952380952381
