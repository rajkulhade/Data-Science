# %%
import pandas as pd
import numpy as np

# %%
dfsales = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\Groupby\\gbsales.csv")

# %%
dfsales
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
dfsales.isnull().sum()
# Out:
# Account     0
# Name        0
# Rep         0
# Manager     0
# Product     0
# Quantity    0
# Price       0
# Status      0
# dtype: int64

# %%
dfsales.columns
# Out:
# Index(['Account', 'Name', 'Rep', 'Manager', 'Product', 'Quantity', 'Price',
#        'Status'],
#       dtype='object')

# %%
len( dfsales["Name"].unique() )
# Out:
# 12

# %%
len(dfsales["Rep"].unique())
# Out:
# 5

# %%
dfsales["Manager"].unique()
# Out:
# array(['Debra Henley', 'Fred Anderson'], dtype=object)

# %%
gbmanager = dfsales.groupby("Manager")

# %%
gbmanager

# %%
gbmanager.groups
# Out:
# {'Debra Henley': [0, 1, 2, 3, 4, 5, 6, 7, 8], 'Fred Anderson': [9, 10, 11, 12, 13, 14, 15, 16]}

# %%
for x, y in gbmanager:
    print(x)
    print()
    print(y)
    print()
    print("*******************************")
    print()
# Out:
# Debra Henley
#
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
# 5   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 6   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 7   412290                 Jerde-Hilpert     John Smith  Debra Henley
# 8   740150                    Barton LLC     John Smith  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# ...

# %%
dfdebra = gbmanager.get_group("Debra Henley")

# %%
dffred = gbmanager.get_group("Fred Anderson")

# %%
dfdebra
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
# 5   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 6   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 7   412290                 Jerde-Hilpert     John Smith  Debra Henley
# 8   740150                    Barton LLC     John Smith  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won
# ...

# %%
dffred
# Out:
#     Account                         Name          Rep        Manager  \
# 9    141962                   Herman LLC  Cedric Moss  Fred Anderson
# 10   163416                  Purdy-Kunde  Cedric Moss  Fred Anderson
# 11   239344                   Stokes LLC  Cedric Moss  Fred Anderson
# 12   239344                   Stokes LLC  Cedric Moss  Fred Anderson
# 13   307599  Kassulke, Ondricka and Metz   Wendy Yule  Fred Anderson
# 14   688981                  Keeling LLC   Wendy Yule  Fred Anderson
# 15   729833                    Koepp Ltd   Wendy Yule  Fred Anderson
# 16   729833                    Koepp Ltd   Wendy Yule  Fred Anderson
#
#         Product  Quantity   Price     Status
# 9           CPU         2   65000        won
# 10          CPU         1   30000  presented
# 11  Maintenance         1    5000    pending
# 12     Software         1   10000  presented
# 13  Maintenance         3    7000        won
# 14          CPU         5  100000        won
# ...

# %%
dfdebra
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
# 5   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 6   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 7   412290                 Jerde-Hilpert     John Smith  Debra Henley
# 8   740150                    Barton LLC     John Smith  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won
# ...

# %%
dfdebra["Rep"]
# Out:
# 0     Craig Booker
# 1     Craig Booker
# 2     Craig Booker
# 3     Craig Booker
# 4    Daniel Hilton
# 5    Daniel Hilton
# 6    Daniel Hilton
# 7       John Smith
# 8       John Smith
# Name: Rep, dtype: object

# %%
dfdebra["Rep"].unique()
# Out:
# array(['Craig Booker', 'Daniel Hilton', 'John Smith'], dtype=object)

# %% [markdown]
# #### NESTED GROUPBY

# %%
dfdebra
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
# 5   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 6   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 7   412290                 Jerde-Hilpert     John Smith  Debra Henley
# 8   740150                    Barton LLC     John Smith  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won
# ...

# %%
gbrep = dfdebra.groupby("Rep")

# %%
gbrep.groups
# Out:
# {'Craig Booker': [0, 1, 2, 3], 'Daniel Hilton': [4, 5, 6], 'John Smith': [7, 8]}

# %%
for a, b in gbrep :
    print(a)
    print()
    print(b)
    print()
    print("*********************")
    print()
# Out:
# Craig Booker
#
#    Account                          Name           Rep       Manager  \
# 0   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson  Craig Booker  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
#
# *********************
#
# Daniel Hilton
#
#    Account          Name            Rep       Manager   Product  Quantity  \
# 4   146832  Kiehn-Spinka  Daniel Hilton  Debra Henley       CPU         2
# 5   218895     Kulas Inc  Daniel Hilton  Debra Henley       CPU         2
# 6   218895     Kulas Inc  Daniel Hilton  Debra Henley  Software         1
#
#    Price     Status
# ...

# %%
for a , b in gbrep :
    print(a)
    print()
    print(b)
# Out:
# Craig Booker
#
#    Account                          Name           Rep       Manager  \
# 0   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson  Craig Booker  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# Daniel Hilton
#
#    Account          Name            Rep       Manager   Product  Quantity  \
# 4   146832  Kiehn-Spinka  Daniel Hilton  Debra Henley       CPU         2
# 5   218895     Kulas Inc  Daniel Hilton  Debra Henley       CPU         2
# 6   218895     Kulas Inc  Daniel Hilton  Debra Henley  Software         1
#
#    Price     Status
# 4  65000        won
# 5  40000    pending
# ...

# %%
for a , b in gbrep :
    print(a)
    print()
    print(b["Price"])
# Out:
# Craig Booker
#
# 0    30000
# 1    10000
# 2     5000
# 3    35000
# Name: Price, dtype: int64
# Daniel Hilton
#
# 4    65000
# 5    40000
# 6    10000
# Name: Price, dtype: int64
# John Smith
#
# 7     5000
# 8    35000
# Name: Price, dtype: int64

# %%
for a , b in gbrep :
    print(a)
    print()
    print(b["Price"].sum())
    print("**********************")
# Out:
# Craig Booker
#
# 80000
# **********************
# Daniel Hilton
#
# 115000
# **********************
# John Smith
#
# 40000
# **********************

# %%
dfsales
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
dfdebra["Status"] == "declined"
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# Name: Status, dtype: bool

# %%
ft = dfsales["Status"] == "declined"

# %%
ft
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# Name: Status, dtype: bool

# %%
dfdebra.loc[ft]
# Out:
#    Account                          Name           Rep       Manager Product  \
# 3   737550  Fritsch, Russel and Anderson  Craig Booker  Debra Henley     CPU
# 8   740150                    Barton LLC    John Smith  Debra Henley     CPU
#
#    Quantity  Price    Status
# 3         1  35000  declined
# 8         1  35000  declined

# %%
dfdebra.loc[~ft]
# Out:
#    Account             Name            Rep       Manager      Product  \
# 0   714466  Trantow-Barrows   Craig Booker  Debra Henley          CPU
# 1   714466  Trantow-Barrows   Craig Booker  Debra Henley     Software
# 2   714466  Trantow-Barrows   Craig Booker  Debra Henley  Maintenance
# 4   146832     Kiehn-Spinka  Daniel Hilton  Debra Henley          CPU
# 5   218895        Kulas Inc  Daniel Hilton  Debra Henley          CPU
# 6   218895        Kulas Inc  Daniel Hilton  Debra Henley     Software
# 7   412290    Jerde-Hilpert     John Smith  Debra Henley  Maintenance
#
#    Quantity  Price     Status
# 0         1  30000  presented
# 1         1  10000  presented
# 2         2   5000    pending
# 4         2  65000        won
# 5         2  40000    pending
# 6         1  10000  presented
# 7         2   5000    pending

# %%
dfdebra
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
# 5   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 6   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 7   412290                 Jerde-Hilpert     John Smith  Debra Henley
# 8   740150                    Barton LLC     John Smith  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won
# ...

# %%
dfdebra["Status"]
# Out:
# 0    presented
# 1    presented
# 2      pending
# 3     declined
# 4          won
# 5      pending
# 6    presented
# 7      pending
# 8     declined
# Name: Status, dtype: object

# %%
dfdebra["Status"] == "declined"
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# Name: Status, dtype: bool

# %%
dfdebra["Status"] != "declined"
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8    False
# Name: Status, dtype: bool

# %%
dfdebra[  dfdebra["Status"] == "declined" ]
# Out:
#    Account                          Name           Rep       Manager Product  \
# 3   737550  Fritsch, Russel and Anderson  Craig Booker  Debra Henley     CPU
# 8   740150                    Barton LLC    John Smith  Debra Henley     CPU
#
#    Quantity  Price    Status
# 3         1  35000  declined
# 8         1  35000  declined

# %%
dfdebranon = dfdebra[ dfdebra["Status"] != "declined" ]

# %%
dfdebranon
# Out:
#    Account             Name            Rep       Manager      Product  \
# 0   714466  Trantow-Barrows   Craig Booker  Debra Henley          CPU
# 1   714466  Trantow-Barrows   Craig Booker  Debra Henley     Software
# 2   714466  Trantow-Barrows   Craig Booker  Debra Henley  Maintenance
# 4   146832     Kiehn-Spinka  Daniel Hilton  Debra Henley          CPU
# 5   218895        Kulas Inc  Daniel Hilton  Debra Henley          CPU
# 6   218895        Kulas Inc  Daniel Hilton  Debra Henley     Software
# 7   412290    Jerde-Hilpert     John Smith  Debra Henley  Maintenance
#
#    Quantity  Price     Status
# 0         1  30000  presented
# 1         1  10000  presented
# 2         2   5000    pending
# 4         2  65000        won
# 5         2  40000    pending
# 6         1  10000  presented
# 7         2   5000    pending

# %%
gbrep1 = dfdebranon.groupby("Rep")

# %%
gbrep1

# %%
gbrep1.groups
# Out:
# {'Craig Booker': [0, 1, 2], 'Daniel Hilton': [4, 5, 6], 'John Smith': [7]}

# %%
for m,n in gbrep1:
    print(m)
    print()
    print(n)
# Out:
# Craig Booker
#
#    Account             Name           Rep       Manager      Product  \
# 0   714466  Trantow-Barrows  Craig Booker  Debra Henley          CPU
# 1   714466  Trantow-Barrows  Craig Booker  Debra Henley     Software
# 2   714466  Trantow-Barrows  Craig Booker  Debra Henley  Maintenance
#
#    Quantity  Price     Status
# 0         1  30000  presented
# 1         1  10000  presented
# 2         2   5000    pending
# Daniel Hilton
#
#    Account          Name            Rep       Manager   Product  Quantity  \
# 4   146832  Kiehn-Spinka  Daniel Hilton  Debra Henley       CPU         2
# 5   218895     Kulas Inc  Daniel Hilton  Debra Henley       CPU         2
# 6   218895     Kulas Inc  Daniel Hilton  Debra Henley  Software         1
#
#    Price     Status
# 4  65000        won
# 5  40000    pending
# 6  10000  presented
# John Smith
#
#    Account           Name         Rep       Manager      Product  Quantity  \
# ...

# %%
for m,n in gbrep1:
    print(m)
    print()
    print(n["Price"])
# Out:
# Craig Booker
#
# 0    30000
# 1    10000
# 2     5000
# Name: Price, dtype: int64
# Daniel Hilton
#
# 4    65000
# 5    40000
# 6    10000
# Name: Price, dtype: int64
# John Smith
#
# 7    5000
# Name: Price, dtype: int64

# %%
for m,n in gbrep1:
    print(m)
    print()
    print(n["Price"].max())
# Out:
# Craig Booker
#
# 30000
# Daniel Hilton
#
# 65000
# John Smith
#
# 5000

# %% [markdown]
# ### Maximum by a Rep

# %%
dfsales
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
ft = dfsales["Status"] != "declined"

# %%
ft
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16     True
# Name: Status, dtype: bool

# %%
dfsalesnon = dfsales[ ft ]

# %%
dfsalesnon
# Out:
#     Account                         Name            Rep        Manager  \
# 0    714466              Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466              Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466              Trantow-Barrows   Craig Booker   Debra Henley
# 4    146832                 Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                    Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                    Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                Jerde-Hilpert     John Smith   Debra Henley
# 9    141962                   Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                  Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                   Stokes LLC    Cedric Moss  Fred Anderson
# 12   239344                   Stokes LLC    Cedric Moss  Fred Anderson
# 13   307599  Kassulke, Ondricka and Metz     Wendy Yule  Fred Anderson
# ...

# %%
dfsalesnon["Price"].max()
# Out:
# 100000

# %%
gbrep2 = dfsalesnon.groupby("Rep")

# %%
for c, d in gbrep2:
    print(c)
    print()
    print(d)
    print()
# Out:
# Cedric Moss
#
#     Account         Name          Rep        Manager      Product  Quantity  \
# 9    141962   Herman LLC  Cedric Moss  Fred Anderson          CPU         2
# 10   163416  Purdy-Kunde  Cedric Moss  Fred Anderson          CPU         1
# 11   239344   Stokes LLC  Cedric Moss  Fred Anderson  Maintenance         1
# 12   239344   Stokes LLC  Cedric Moss  Fred Anderson     Software         1
#
#     Price     Status
# 9   65000        won
# 10  30000  presented
# 11   5000    pending
# 12  10000  presented
#
# Craig Booker
#
#    Account             Name           Rep       Manager      Product  \
# 0   714466  Trantow-Barrows  Craig Booker  Debra Henley          CPU
# 1   714466  Trantow-Barrows  Craig Booker  Debra Henley     Software
# 2   714466  Trantow-Barrows  Craig Booker  Debra Henley  Maintenance
#
#    Quantity  Price     Status
# 0         1  30000  presented
# 1         1  10000  presented
# 2         2   5000    pending
#
# Daniel Hilton
#
# ...

# %%
for c, d in gbrep2:
    print(c)
    print()
    print(d["Price"])
    print()
# Out:
# Cedric Moss
#
# 9     65000
# 10    30000
# 11     5000
# 12    10000
# Name: Price, dtype: int64
#
# Craig Booker
#
# 0    30000
# 1    10000
# 2     5000
# Name: Price, dtype: int64
#
# Daniel Hilton
#
# 4    65000
# 5    40000
# 6    10000
# Name: Price, dtype: int64
#
# John Smith
#
# 7    5000
# Name: Price, dtype: int64
#
# Wendy Yule
#
# 13      7000
# 14    100000
# 16      5000
# Name: Price, dtype: int64

# %%
for c, d in gbrep2:
    print(c)
    print()
    print(d["Price"].sum())
    print()
# Out:
# Cedric Moss
#
# 110000
#
# Craig Booker
#
# 45000
#
# Daniel Hilton
#
# 115000
#
# John Smith
#
# 5000
#
# Wendy Yule
#
# 112000

# %% [markdown]
# ### Groupby Multi Column

# %%
dfprod = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\Crosstab\\Crosstab_Sales.csv")

# %%
dfprod
# Out:
#            Date Region                 Type  Units      Sales
# 0     7/11/2020   East  Children's Clothing   18.0    $306.00
# 1     9/23/2020  North  Children's Clothing   14.0    $448.00
# 2      4/2/2020  South     Women's Clothing   17.0    $425.00
# 3     2/28/2020   East  Children's Clothing   26.0    $832.00
# 4     3/19/2020   West     Women's Clothing    3.0     $33.00
# ..          ...    ...                  ...    ...        ...
# 995   2/11/2020   East  Children's Clothing   35.0    $735.00
# 996  12/25/2020  North       Men's Clothing    NaN  $1,155.00
# 997   8/31/2020  South       Men's Clothing   13.0    $208.00
# 998   8/23/2020  South     Women's Clothing   17.0    $493.00
# 999   8/17/2020  North     Women's Clothing   25.0    $300.00
#
# [1000 rows x 5 columns]

# %%
dfsales
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
gbname = dfsales.groupby("Name")

# %%
for x, y in gbname :
    print(x)
    print()
    print(y)
    print()
    print("*******************")
    print()
# Out:
# Barton LLC
#
#    Account        Name         Rep       Manager Product  Quantity  Price  \
# 8   740150  Barton LLC  John Smith  Debra Henley     CPU         1  35000
#
#      Status
# 8  declined
#
# *******************
#
# Fritsch, Russel and Anderson
#
#    Account                          Name           Rep       Manager Product  \
# 3   737550  Fritsch, Russel and Anderson  Craig Booker  Debra Henley     CPU
#
#    Quantity  Price    Status
# 3         1  35000  declined
#
# *******************
#
# Herman LLC
#
#    Account        Name          Rep        Manager Product  Quantity  Price  \
# 9   141962  Herman LLC  Cedric Moss  Fred Anderson     CPU         2  65000
#
#   Status
# 9    won
#
# *******************
#
# Jerde-Hilpert
#
#    Account           Name         Rep       Manager      Product  Quantity  \
# 7   412290  Jerde-Hilpert  John Smith  Debra Henley  Maintenance         2
#
#    Price   Status
# 7   5000  pending
#
# *******************
#
# ...

# %%
gbmag = dfsales.groupby("Manager")

# %%
for x, y in gbmag :
    print(x)
    print()
    print(y)
    print()
    print("*******************")
    print()
# Out:
# Debra Henley
#
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
# 5   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 6   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 7   412290                 Jerde-Hilpert     John Smith  Debra Henley
# 8   740150                    Barton LLC     John Smith  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# ...

# %%
dfdeb = gbmag.get_group("Debra Henley")

# %%
dfdeb
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
# 5   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 6   218895                     Kulas Inc  Daniel Hilton  Debra Henley
# 7   412290                 Jerde-Hilpert     John Smith  Debra Henley
# 8   740150                    Barton LLC     John Smith  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won
# ...

# %%
gbrep5 = dfdeb.groupby("Rep")

# %%
for x1, y1 in gbrep5 :
    print(x1)
    print()
    print(y1)
    print()
    print("*******************")
    print()
# Out:
# Craig Booker
#
#    Account                          Name           Rep       Manager  \
# 0   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson  Craig Booker  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
#
# *******************
#
# Daniel Hilton
#
#    Account          Name            Rep       Manager   Product  Quantity  \
# 4   146832  Kiehn-Spinka  Daniel Hilton  Debra Henley       CPU         2
# 5   218895     Kulas Inc  Daniel Hilton  Debra Henley       CPU         2
# 6   218895     Kulas Inc  Daniel Hilton  Debra Henley  Software         1
#
#    Price     Status
# 4  65000        won
# ...

# %%
gbmrep = dfsales.groupby(["Manager","Rep"])

# %%
for a1, b1 in gbmrep:
    print(a1)
    print()
    print(b1)
    print("**********************")
    print()
# Out:
# ('Debra Henley', 'Craig Booker')
#
#    Account                          Name           Rep       Manager  \
# 0   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson  Craig Booker  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# **********************
#
# ('Debra Henley', 'Daniel Hilton')
#
#    Account          Name            Rep       Manager   Product  Quantity  \
# 4   146832  Kiehn-Spinka  Daniel Hilton  Debra Henley       CPU         2
# 5   218895     Kulas Inc  Daniel Hilton  Debra Henley       CPU         2
# 6   218895     Kulas Inc  Daniel Hilton  Debra Henley  Software         1
#
# ...

# %%
gbmrep.get_group(('Debra Henley', 'Craig Booker'))
# Out:
#    Account                          Name           Rep       Manager  \
# 0   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows  Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson  Craig Booker  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined

# %%
gbmrep.get_group(('Debra Henley', 'Craig Booker'))["Price"]
# Out:
# 0    30000
# 1    10000
# 2     5000
# 3    35000
# Name: Price, dtype: int64

# %%
gbmrep.get_group(('Debra Henley', 'Craig Booker'))["Price"].sum()
# Out:
# 80000

# %%
gbmrep1 = dfsales.groupby(["Manager","Rep", "Name"])

for a2, b2 in gbmrep1:
    print(a2)
    print()
    print(b2)
    print("**********************")
    print()
# Out:
# ('Debra Henley', 'Craig Booker', 'Fritsch, Russel and Anderson')
#
#    Account                          Name           Rep       Manager Product  \
# 3   737550  Fritsch, Russel and Anderson  Craig Booker  Debra Henley     CPU
#
#    Quantity  Price    Status
# 3         1  35000  declined
# **********************
#
# ('Debra Henley', 'Craig Booker', 'Trantow-Barrows')
#
#    Account             Name           Rep       Manager      Product  \
# 0   714466  Trantow-Barrows  Craig Booker  Debra Henley          CPU
# 1   714466  Trantow-Barrows  Craig Booker  Debra Henley     Software
# 2   714466  Trantow-Barrows  Craig Booker  Debra Henley  Maintenance
#
#    Quantity  Price     Status
# 0         1  30000  presented
# 1         1  10000  presented
# 2         2   5000    pending
# **********************
#
# ('Debra Henley', 'Daniel Hilton', 'Kiehn-Spinka')
#
#    Account          Name            Rep       Manager Product  Quantity  \
# ...

# %%
gbmrep1 = dfsales.groupby(["Name","Manager", "Rep"])

for a2, b2 in gbmrep1:
    print(a2)
    print()
    print(b2)
    print("**********************")
    print()
# Out:
# ('Barton LLC', 'Debra Henley', 'John Smith')
#
#    Account        Name         Rep       Manager Product  Quantity  Price  \
# 8   740150  Barton LLC  John Smith  Debra Henley     CPU         1  35000
#
#      Status
# 8  declined
# **********************
#
# ('Fritsch, Russel and Anderson', 'Debra Henley', 'Craig Booker')
#
#    Account                          Name           Rep       Manager Product  \
# 3   737550  Fritsch, Russel and Anderson  Craig Booker  Debra Henley     CPU
#
#    Quantity  Price    Status
# 3         1  35000  declined
# **********************
#
# ('Herman LLC', 'Fred Anderson', 'Cedric Moss')
#
#    Account        Name          Rep        Manager Product  Quantity  Price  \
# 9   141962  Herman LLC  Cedric Moss  Fred Anderson     CPU         2  65000
#
#   Status
# 9    won
# **********************
#
# ('Jerde-Hilpert', 'Debra Henley', 'John Smith')
#
#    Account           Name         Rep       Manager      Product  Quantity  \
# ...

# %%
dfprod
# Out:
#            Date Region                 Type  Units      Sales
# 0     7/11/2020   East  Children's Clothing   18.0    $306.00
# 1     9/23/2020  North  Children's Clothing   14.0    $448.00
# 2      4/2/2020  South     Women's Clothing   17.0    $425.00
# 3     2/28/2020   East  Children's Clothing   26.0    $832.00
# 4     3/19/2020   West     Women's Clothing    3.0     $33.00
# ..          ...    ...                  ...    ...        ...
# 995   2/11/2020   East  Children's Clothing   35.0    $735.00
# 996  12/25/2020  North       Men's Clothing    NaN  $1,155.00
# 997   8/31/2020  South       Men's Clothing   13.0    $208.00
# 998   8/23/2020  South     Women's Clothing   17.0    $493.00
# 999   8/17/2020  North     Women's Clothing   25.0    $300.00
#
# [1000 rows x 5 columns]

# %%
dfprod["Type"].unique()
# Out:
# array(["Children's Clothing", "Women's Clothing", "Men's Clothing"],
#       dtype=object)

# %%
dfprod["Region"].unique()
# Out:
# array(['East', 'North', 'South', 'West'], dtype=object)
