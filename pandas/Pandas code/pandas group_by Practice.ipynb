# %%
import pandas as pd
import numpy as np

# %%
dfgen=pd.read_csv(r"C:\Users\admin\Desktop\Pandas\arjun srikant pandas\Gb_gender.csv")

# %%
dfgen
# Out:
#     Gender  Degree  Height        City
# 0     Male    B.Sc     174   Hyderabad
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 3     Male   B.Com     173       Delhi
# 4     Male     MBA     177      Jaipur
# ..     ...     ...     ...         ...
# 76  Female    B.Sc     176   Hyderabad
# 77    Male     MCA     178     Chennai
# 78  Female    B.Sc     178   Hyderabad
# 79    Male  B.Tech     174  Chandigarh
# 80    Male  M.Tech     175     Lucknow
#
# [81 rows x 4 columns]

# %%
gbgen=dfgen.groupby("Gender")

# %%
gbgen

# %%
gbgen.groups
# Out:
# {'Female': [1, 2, 6, 7, 8, 10, 12, 13, 17, 18, 19, 21, 22, 28, 29, 30, 32, 34, 35, 39, 40, 41, 42, 44, 46, 47, 51, 52, 53, 55, 56, 62, 63, 64, 66, 68, 70, 71, 73, 75, 76, 78], 'Male': [0, 3, 4, 5, 9, 11, 14, 15, 16, 20, 23, 24, 25, 26, 27, 31, 33, 36, 37, 38, 43, 45, 48, 49, 50, 54, 57, 58, 59, 60, 61, 65, 67, 69, 72, 74, 77, 79, 80]}

# %%
dfgen.head()
# Out:
#    Gender  Degree  Height       City
# 0    Male    B.Sc     174  Hyderabad
# 1  Female  B.Tech     167    Chennai
# 2  Female     B.E     169      Vizag
# 3    Male   B.Com     173      Delhi
# 4    Male     MBA     177     Jaipur

# %%
for i in gbgen:
    print(i)
# Out:
# ('Female',     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# 41  Female  M.Tech     171      Jaipur
# 42  Female    B.Sc     173  Chandigarh
# ...

# %%
for x,y in gbgen:
    print(x)
    print("-"*50)
    print(y)
    print("-"*50)
# Out:
# Female
# --------------------------------------------------
#     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# ...

# %%
for x,y in gbgen:
    print(x)
    print("-"*50)
    print()
    print(y)
    print("-"*50)
    print()
# Out:
# Female
# --------------------------------------------------
#
#     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# ...

# %%
dffemale=gbgen.get_group("Female")

# %%
dffemale["Height"]
# Out:
# 1     167
# 2     169
# 6     172
# 7     172
# 8     179
# 10    173
# 12    174
# 13    168
# 17    178
# 18    175
# 19    177
# 21    171
# 22    167
# 28    172
# 29    172
# 30    166
# 32    176
# 34    168
# 35    166
# 39    175
# 40    177
# 41    171
# 42    173
# 44    178
# 46    172
# 47    179
# 51    174
# 52    168
# 53    166
# 55    166
# 56    178
# 62    173
# 63    175
# 64    173
# 66    178
# 68    172
# 70    179
# 71    175
# 73    179
# 75    179
# 76    176
# 78    178
# Name: Height, dtype: int64

# %%
dffemale["Height"].max()
# Out:
# 179

# %%
dffemale["Height"] == dffemale["Height"].max()
# Out:
# 1     False
# 2     False
# 6     False
# 7     False
# 8      True
# 10    False
# 12    False
# 13    False
# 17    False
# 18    False
# 19    False
# 21    False
# 22    False
# 28    False
# 29    False
# 30    False
# 32    False
# 34    False
# 35    False
# 39    False
# 40    False
# 41    False
# 42    False
# 44    False
# 46    False
# 47     True
# 51    False
# 52    False
# 53    False
# 55    False
# 56    False
# 62    False
# 63    False
# 64    False
# 66    False
# 68    False
# 70     True
# 71    False
# 73     True
# 75     True
# 76    False
# 78    False
# Name: Height, dtype: bool

# %%
ft1=(dffemale["Height"] == dffemale["Height"].max())

# %%
ft1
# Out:
# 1     False
# 2     False
# 6     False
# 7     False
# 8      True
# 10    False
# 12    False
# 13    False
# 17    False
# 18    False
# 19    False
# 21    False
# 22    False
# 28    False
# 29    False
# 30    False
# 32    False
# 34    False
# 35    False
# 39    False
# 40    False
# 41    False
# 42    False
# 44    False
# 46    False
# 47     True
# 51    False
# 52    False
# 53    False
# 55    False
# 56    False
# 62    False
# 63    False
# 64    False
# 66    False
# 68    False
# 70     True
# 71    False
# 73     True
# 75     True
# 76    False
# 78    False
# Name: Height, dtype: bool

# %%
dffemale[ft1]
# Out:
#     Gender  Degree  Height       City
# 8   Female    B.Sc     179  Bangalore
# 47  Female    M.Sc     179      Delhi
# 70  Female  M.Tech     179  Hyderabad
# 73  Female     MBA     179     Bhopal
# 75  Female  M.Tech     179      Vizag

# %%
dfmale=gbgen.get_group("Male")

# %%
dfmale
# Out:
#    Gender  Degree  Height        City
# 0    Male    B.Sc     174   Hyderabad
# 3    Male   B.Com     173       Delhi
# 4    Male     MBA     177      Jaipur
# 5    Male    M.Sc     178  Chandigarh
# 9    Male  B.Tech     166   Hyderabad
# 11   Male   B.Com     176       Vizag
# 14   Male  M.Tech     166  Chandigarh
# 15   Male     MCA     175     Lucknow
# 16   Male   B.Com     166      Bhopal
# 20   Male     MCA     171  Chandigarh
# 23   Male     B.E     173   Bangalore
# 24   Male   B.Com     175   Hyderabad
# 25   Male   B.Com     173       Delhi
# 26   Male     MBA     177      Jaipur
# 27   Male    M.Sc     178  Chandigarh
# 31   Male  B.Tech     173   Hyderabad
# 33   Male   B.Com     174       Vizag
# 36   Male  M.Tech     175  Chandigarh
# 37   Male     MCA     166     Lucknow
# 38   Male   B.Com     178      Bhopal
# 43   Male  B.Tech     177     Lucknow
# 45   Male   B.Com     172   Bangalore
# 48   Male  M.Tech     166      Jaipur
# 49   Male     MCA     173  Chandigarh
# ...

# %%
dfmale["Height"].max()
# Out:
# 178

# %%
dfmale
# Out:
#    Gender  Degree  Height        City
# 0    Male    B.Sc     174   Hyderabad
# 3    Male   B.Com     173       Delhi
# 4    Male     MBA     177      Jaipur
# 5    Male    M.Sc     178  Chandigarh
# 9    Male  B.Tech     166   Hyderabad
# 11   Male   B.Com     176       Vizag
# 14   Male  M.Tech     166  Chandigarh
# 15   Male     MCA     175     Lucknow
# 16   Male   B.Com     166      Bhopal
# 20   Male     MCA     171  Chandigarh
# 23   Male     B.E     173   Bangalore
# 24   Male   B.Com     175   Hyderabad
# 25   Male   B.Com     173       Delhi
# 26   Male     MBA     177      Jaipur
# 27   Male    M.Sc     178  Chandigarh
# 31   Male  B.Tech     173   Hyderabad
# 33   Male   B.Com     174       Vizag
# 36   Male  M.Tech     175  Chandigarh
# 37   Male     MCA     166     Lucknow
# 38   Male   B.Com     178      Bhopal
# 43   Male  B.Tech     177     Lucknow
# 45   Male   B.Com     172   Bangalore
# 48   Male  M.Tech     166      Jaipur
# 49   Male     MCA     173  Chandigarh
# ...

# %%
dfmale["Height"].max()
# Out:
# 178

# %%
dfmale["Height"]==dfmale["Height"].max()
# Out:
# 0     False
# 3     False
# 4     False
# 5      True
# 9     False
# 11    False
# 14    False
# 15    False
# 16    False
# 20    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 31    False
# 33    False
# 36    False
# 37    False
# 38     True
# 43    False
# 45    False
# 48    False
# 49    False
# 50    False
# 54    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 65    False
# 67    False
# 69    False
# 72     True
# 74     True
# 77     True
# 79    False
# 80    False
# Name: Height, dtype: bool

# %%
ftmale=dfmale["Height"]==dfmale["Height"].max()

# %%
ftmale
# Out:
# 0     False
# 3     False
# 4     False
# 5      True
# 9     False
# 11    False
# 14    False
# 15    False
# 16    False
# 20    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 31    False
# 33    False
# 36    False
# 37    False
# 38     True
# 43    False
# 45    False
# 48    False
# 49    False
# 50    False
# 54    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 65    False
# 67    False
# 69    False
# 72     True
# 74     True
# 77     True
# 79    False
# 80    False
# Name: Height, dtype: bool

# %%
dfmale[ftmale]
# Out:
#    Gender Degree  Height        City
# 5    Male   M.Sc     178  Chandigarh
# 27   Male   M.Sc     178  Chandigarh
# 38   Male  B.Com     178      Bhopal
# 72   Male  B.Com     178      Jaipur
# 74   Male   M.Sc     178       Vizag
# 77   Male    MCA     178     Chennai

# %%
dfmresult=dfmale[ftmale]

# %%
dffresult=dffemale[ft1]

# %%
display(dfmresult,dffresult)
# Out:
#    Gender Degree  Height        City
# 5    Male   M.Sc     178  Chandigarh
# 27   Male   M.Sc     178  Chandigarh
# 38   Male  B.Com     178      Bhopal
# 72   Male  B.Com     178      Jaipur
# 74   Male   M.Sc     178       Vizag
# 77   Male    MCA     178     Chennai
#     Gender  Degree  Height       City
# 8   Female    B.Sc     179  Bangalore
# 47  Female    M.Sc     179      Delhi
# 70  Female  M.Tech     179  Hyderabad
# 73  Female     MBA     179     Bhopal
# 75  Female  M.Tech     179      Vizag

# %%
dfselected=pd.concat([dffresult,dfmresult])

# %%
dfselected=dfselected.reset_index()

# %%
dfselected
# Out:
#     index  Gender  Degree  Height        City
# 0       8  Female    B.Sc     179   Bangalore
# 1      47  Female    M.Sc     179       Delhi
# 2      70  Female  M.Tech     179   Hyderabad
# 3      73  Female     MBA     179      Bhopal
# 4      75  Female  M.Tech     179       Vizag
# 5       5    Male    M.Sc     178  Chandigarh
# 6      27    Male    M.Sc     178  Chandigarh
# 7      38    Male   B.Com     178      Bhopal
# 8      72    Male   B.Com     178      Jaipur
# 9      74    Male    M.Sc     178       Vizag
# 10     77    Male     MCA     178     Chennai
