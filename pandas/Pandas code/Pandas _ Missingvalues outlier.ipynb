# %%
import pandas as pd
import numpy as np

# %%
dftemp1 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\Temp.csv" )

# %%
dftemp1
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0         35     36         0
# 1         30     -2        -1
# 2         36     28        -3
# 3          0     32        -2
# 4         28      2         2
# 5         32     30        30

# %%
df1 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\std_data3.csv", na_values= ["TEN", 999, 830] )

# %%
df1
# Out:
#   Name  Class  English  Science  Maths
# 0    A   10.0     67.0     66.0   66.0
# 1    B   12.0     87.0     56.0    NaN
# 2    C   11.0      NaN     89.0   63.0
# 3    D    NaN     56.0     88.0    NaN
# 4    E   10.0     89.0      NaN   56.0
# 5    F    9.0     88.0     85.0    NaN
# 6    G   12.0      NaN      NaN    NaN
# 7    H   11.0     79.0     88.0   90.0

# %%
dftemp1 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\Temp.csv" )

# %%
dftemp1
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0         35     36         0
# 1         30     -2        -1
# 2         36     28        -3
# 3          0     32        -2
# 4         28      2         2
# 5         32     30        30

# %%
d1 = {
    
    "Hyderabad" : [0],
    "DELHI" : [-2,2],
    "SRINAGAR" : [30]
    
}

# %%
dftemp1 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\Temp.csv", na_values=d1 )

# %%
dftemp1
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0       35.0   36.0       0.0
# 1       30.0    NaN      -1.0
# 2       36.0   28.0      -3.0
# 3        NaN   32.0      -2.0
# 4       28.0    NaN       2.0
# 5       32.0   30.0       NaN

# %%
dftemp2 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\Temp.csv", na_values= {
    
    "Hyderabad" : [0],
    "DELHI" : [-2,2],
    "SRINAGAR" : [30]
    
} )

# %%
dftemp2
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0       35.0   36.0       0.0
# 1       30.0    NaN      -1.0
# 2       36.0   28.0      -3.0
# 3        NaN   32.0      -2.0
# 4       28.0    NaN       2.0
# 5       32.0   30.0       NaN

# %%
dftemp1
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0       35.0   36.0       0.0
# 1       30.0    NaN      -1.0
# 2       36.0   28.0      -3.0
# 3        NaN   32.0      -2.0
# 4       28.0    NaN       2.0
# 5       32.0   30.0       NaN

# %%
df1
# Out:
#   Name  Class  English  Science  Maths
# 0    A   10.0     67.0     66.0   66.0
# 1    B   12.0     87.0     56.0    NaN
# 2    C   11.0      NaN     89.0   63.0
# 3    D    NaN     56.0     88.0    NaN
# 4    E   10.0     89.0      NaN   56.0
# 5    F    9.0     88.0     85.0    NaN
# 6    G   12.0      NaN      NaN    NaN
# 7    H   11.0     79.0     88.0   90.0

# %%
df1.isnull()
# Out:
#     Name  Class  English  Science  Maths
# 0  False  False    False    False  False
# 1  False  False    False    False   True
# 2  False  False     True    False  False
# 3  False   True    False    False   True
# 4  False  False    False     True  False
# 5  False  False    False    False   True
# 6  False  False     True     True   True
# 7  False  False    False    False  False

# %%
df1.isnull().sum()
# Out:
# Name       0
# Class      1
# English    2
# Science    2
# Maths      4
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 9

# %% [markdown]
# #### NOTNULL

# %%
df1.notnull()
# Out:
#    Name  Class  English  Science  Maths
# 0  True   True     True     True   True
# 1  True   True     True     True  False
# 2  True   True    False     True   True
# 3  True  False     True     True  False
# 4  True   True     True    False   True
# 5  True   True     True     True  False
# 6  True   True    False    False  False
# 7  True   True     True     True   True

# %%
df1.notnull().sum()
# Out:
# Name       8
# Class      7
# English    6
# Science    6
# Maths      4
# dtype: int64

# %%
df1.notnull().sum().sum()
# Out:
# 31

# %%
df1
# Out:
#   Name  Class  English  Science  Maths
# 0    A   10.0     67.0     66.0   66.0
# 1    B   12.0     87.0     56.0    NaN
# 2    C   11.0      NaN     89.0   63.0
# 3    D    NaN     56.0     88.0    NaN
# 4    E   10.0     89.0      NaN   56.0
# 5    F    9.0     88.0     85.0    NaN
# 6    G   12.0      NaN      NaN    NaN
# 7    H   11.0     79.0     88.0   90.0

# %%
df1.size
# Out:
# 40

# %%
df1.isnull().sum().sum()
# Out:
# 9

# %%
df1.isnull().sum()
# Out:
# Name       0
# Class      1
# English    2
# Science    2
# Maths      4
# dtype: int64

# %%
df1.isna()
# Out:
#     Name  Class  English  Science  Maths
# 0  False  False    False    False  False
# 1  False  False    False    False   True
# 2  False  False     True    False  False
# 3  False   True    False    False   True
# 4  False  False    False     True  False
# 5  False  False    False    False   True
# 6  False  False     True     True   True
# 7  False  False    False    False  False

# %%
df1.notna()
# Out:
#    Name  Class  English  Science  Maths
# 0  True   True     True     True   True
# 1  True   True     True     True  False
# 2  True   True    False     True   True
# 3  True  False     True     True  False
# 4  True   True     True    False   True
# 5  True   True     True     True  False
# 6  True   True    False    False  False
# 7  True   True     True     True   True

# %%
dftemp2 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\Temp.csv" )

# %%
dftemp2
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0         35     36         0
# 1         30     -2        -1
# 2         36     28        -3
# 3          0     32        -2
# 4         28      2         2
# 5         32     30        30

# %%
df2 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\std_data3.csv")

# %%
df2
# Out:
#   Name Class  English  Science  Maths
# 0    A    10     67.0     66.0   66.0
# 1    B    12     87.0     56.0    NaN
# 2    C    11      NaN     89.0   63.0
# 3    D   TEN     56.0     88.0  999.0
# 4    E    10     89.0      NaN   56.0
# 5    F     9     88.0     85.0    NaN
# 6    G    12      NaN    830.0    NaN
# 7    H    11     79.0     88.0   90.0

# %%
df2 = df2.replace(['TEN',830,999], np.nan)

# %%
df2
# Out:
#   Name Class  English  Science  Maths
# 0    A    10     67.0     66.0   66.0
# 1    B    12     87.0     56.0    NaN
# 2    C    11      NaN     89.0   63.0
# 3    D   NaN     56.0     88.0    NaN
# 4    E    10     89.0      NaN   56.0
# 5    F     9     88.0     85.0    NaN
# 6    G    12      NaN      NaN    NaN
# 7    H    11     79.0     88.0   90.0

# %%
df2.replace(np.NaN, 0)
# Out:
#   Name Class  English  Science  Maths
# 0    A    10     67.0     66.0   66.0
# 1    B    12     87.0     56.0    0.0
# 2    C    11      0.0     89.0   63.0
# 3    D     0     56.0     88.0    0.0
# 4    E    10     89.0      0.0   56.0
# 5    F     9     88.0     85.0    0.0
# 6    G    12      0.0      0.0    0.0
# 7    H    11     79.0     88.0   90.0

# %%
df2
# Out:
#   Name Class  English  Science  Maths
# 0    A    10     67.0     66.0   66.0
# 1    B    12     87.0     56.0    NaN
# 2    C    11      NaN     89.0   63.0
# 3    D   NaN     56.0     88.0    NaN
# 4    E    10     89.0      NaN   56.0
# 5    F     9     88.0     85.0    NaN
# 6    G    12      NaN      NaN    NaN
# 7    H    11     79.0     88.0   90.0

# %%
dftemp2
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0         35     36         0
# 1         30     -2        -1
# 2         36     28        -3
# 3          0     32        -2
# 4         28      2         2
# 5         32     30        30

# %%
dftemp2.replace( {"Hyderabad" : 0, "DELHI" : [-2,2], "SRINAGAR" : 30}, np.NaN)
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0       35.0   36.0       0.0
# 1       30.0    NaN      -1.0
# 2       36.0   28.0      -3.0
# 3        NaN   32.0      -2.0
# 4       28.0    NaN       2.0
# 5       32.0   30.0       NaN

# %% [markdown]
# ### FILLNA

# %%
df1
# Out:
#   Name  Class  English  Science  Maths
# 0    A   10.0     67.0     66.0   66.0
# 1    B   12.0     87.0     56.0    NaN
# 2    C   11.0      NaN     89.0   63.0
# 3    D    NaN     56.0     88.0    NaN
# 4    E   10.0     89.0      NaN   56.0
# 5    F    9.0     88.0     85.0    NaN
# 6    G   12.0      NaN      NaN    NaN
# 7    H   11.0     79.0     88.0   90.0

# %%
df1.fillna(60)
# Out:
#   Name  Class  English  Science  Maths
# 0    A   10.0     67.0     66.0   66.0
# 1    B   12.0     87.0     56.0   60.0
# 2    C   11.0     60.0     89.0   63.0
# 3    D   60.0     56.0     88.0   60.0
# 4    E   10.0     89.0     60.0   56.0
# 5    F    9.0     88.0     85.0   60.0
# 6    G   12.0     60.0     60.0   60.0
# 7    H   11.0     79.0     88.0   90.0

# %%
df1
# Out:
#   Name  Class  English  Science  Maths
# 0    A   10.0     67.0     66.0   66.0
# 1    B   12.0     87.0     56.0    NaN
# 2    C   11.0      NaN     89.0   63.0
# 3    D    NaN     56.0     88.0    NaN
# 4    E   10.0     89.0      NaN   56.0
# 5    F    9.0     88.0     85.0    NaN
# 6    G   12.0      NaN      NaN    NaN
# 7    H   11.0     79.0     88.0   90.0

# %%
df1.fillna(method = "ffill")
# Out:
#   Name  Class  English  Science  Maths
# 0    A   10.0     67.0     66.0   66.0
# 1    B   12.0     87.0     56.0   66.0
# 2    C   11.0     87.0     89.0   63.0
# 3    D   11.0     56.0     88.0   63.0
# 4    E   10.0     89.0     88.0   56.0
# 5    F    9.0     88.0     85.0   56.0
# 6    G   12.0     88.0     85.0   56.0
# 7    H   11.0     79.0     88.0   90.0

# %%
df1.fillna(method = "pad") # same as forward fill
# Out:
#   Name  Class  English  Science  Maths
# 0    A   10.0     67.0     66.0   66.0
# 1    B   12.0     87.0     56.0   66.0
# 2    C   11.0     87.0     89.0   63.0
# 3    D   11.0     56.0     88.0   63.0
# 4    E   10.0     89.0     88.0   56.0
# 5    F    9.0     88.0     85.0   56.0
# 6    G   12.0     88.0     85.0   56.0
# 7    H   11.0     79.0     88.0   90.0

# %%
df1
# Out:
#   Name  Class  English  Science  Maths
# 0    A   10.0     67.0     66.0   66.0
# 1    B   12.0     87.0     56.0    NaN
# 2    C   11.0      NaN     89.0   63.0
# 3    D    NaN     56.0     88.0    NaN
# 4    E   10.0     89.0      NaN   56.0
# 5    F    9.0     88.0     85.0    NaN
# 6    G   12.0      NaN      NaN    NaN
# 7    H   11.0     79.0     88.0   90.0

# %%
df1.fillna(method = "backfill")
# Out:
#   Name  Class  English  Science  Maths
# 0    A   10.0     67.0     66.0   66.0
# 1    B   12.0     87.0     56.0   63.0
# 2    C   11.0     56.0     89.0   63.0
# 3    D   10.0     56.0     88.0   56.0
# 4    E   10.0     89.0     85.0   56.0
# 5    F    9.0     88.0     85.0   90.0
# 6    G   12.0     79.0     88.0   90.0
# 7    H   11.0     79.0     88.0   90.0

# %%
df1.fillna(method = "ffill", axis = 1)
# Out:
#   Name Class English Science Maths
# 0    A  10.0    67.0    66.0  66.0
# 1    B  12.0    87.0    56.0  56.0
# 2    C  11.0    11.0    89.0  63.0
# 3    D     D    56.0    88.0  88.0
# 4    E  10.0    89.0    89.0  56.0
# 5    F   9.0    88.0    85.0  85.0
# 6    G  12.0    12.0    12.0  12.0
# 7    H  11.0    79.0    88.0  90.0

# %%
df1.fillna(method = "bfill", axis = 1)
# Out:
#   Name Class English Science Maths
# 0    A  10.0    67.0    66.0  66.0
# 1    B  12.0    87.0    56.0   NaN
# 2    C  11.0    89.0    89.0  63.0
# 3    D  56.0    56.0    88.0   NaN
# 4    E  10.0    89.0    56.0  56.0
# 5    F   9.0    88.0    85.0   NaN
# 6    G  12.0     NaN     NaN   NaN
# 7    H  11.0    79.0    88.0  90.0

# %%
dftemp1
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0       35.0   36.0       0.0
# 1       30.0    NaN      -1.0
# 2       36.0   28.0      -3.0
# 3        NaN   32.0      -2.0
# 4       28.0    NaN       2.0
# 5       32.0   30.0       NaN

# %%
dftemp1.fillna(method = 'ffill')
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0       35.0   36.0       0.0
# 1       30.0   36.0      -1.0
# 2       36.0   28.0      -3.0
# 3       36.0   32.0      -2.0
# 4       28.0   32.0       2.0
# 5       32.0   30.0       2.0

# %%
dftemp1
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0       35.0   36.0       0.0
# 1       30.0    NaN      -1.0
# 2       36.0   28.0      -3.0
# 3        NaN   32.0      -2.0
# 4       28.0    NaN       2.0
# 5       32.0   30.0       NaN

# %%
dftemp1["Hyderabad"].mean()
# Out:
# 32.2

# %%
dftemp1.fillna(32.2)
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0       35.0   36.0       0.0
# 1       30.0   32.2      -1.0
# 2       36.0   28.0      -3.0
# 3       32.2   32.0      -2.0
# 4       28.0   32.2       2.0
# 5       32.0   30.0      32.2

# %%
dictemp = {
    
    "Hyderabad" : dftemp1["Hyderabad"].mean(),
    "DELHI" : dftemp1["DELHI"].mean(),
    "SRINAGAR" : dftemp1["SRINAGAR"].mean()
}

# %%
dictemp
# Out:
# {'Hyderabad': 32.2, 'DELHI': 31.5, 'SRINAGAR': -0.8}

# %%
dftemp1.fillna(dictemp)
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0       35.0   36.0       0.0
# 1       30.0   31.5      -1.0
# 2       36.0   28.0      -3.0
# 3       32.2   32.0      -2.0
# 4       28.0   31.5       2.0
# 5       32.0   30.0      -0.8

# %%
df1
# Out:
#   Name  Class  English  Science  Maths
# 0    A   10.0     67.0     66.0   66.0
# 1    B   12.0     87.0     56.0    NaN
# 2    C   11.0      NaN     89.0   63.0
# 3    D    NaN     56.0     88.0    NaN
# 4    E   10.0     89.0      NaN   56.0
# 5    F    9.0     88.0     85.0    NaN
# 6    G   12.0      NaN      NaN    NaN
# 7    H   11.0     79.0     88.0   90.0

# %%
df3 = df1[["Name", "Class"]]

# %%
df3
# Out:
#   Name  Class
# 0    A   10.0
# 1    B   12.0
# 2    C   11.0
# 3    D    NaN
# 4    E   10.0
# 5    F    9.0
# 6    G   12.0
# 7    H   11.0

# %%
df3["Class"].mode()
# Out:
# 0    10.0
# 1    11.0
# 2    12.0
# dtype: float64

# %%
df3["Class"].mode()[0]
# Out:
# 10.0

# %%
df3.fillna(df3["Class"].mode()[0])
# Out:
#   Name  Class
# 0    A   10.0
# 1    B   12.0
# 2    C   11.0
# 3    D   10.0
# 4    E   10.0
# 5    F    9.0
# 6    G   12.0
# 7    H   11.0

# %%
dfstd = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\std_multinan.csv")

# %%
dfstd
# Out:
#    English  Science
# 0     50.0      40.0
# 1      NaN      45.0
# 2      NaN      58.0
# 3      NaN      90.0
# 4      NaN      55.0
# 5     40.0       NaN
# 6     45.0       NaN
# 7     58.0       NaN
# 8     90.0      90.0

# %%
dfstd.fillna(method = "ffill")
# Out:
#    English  Science
# 0     50.0      40.0
# 1     50.0      45.0
# 2     50.0      58.0
# 3     50.0      90.0
# 4     50.0      55.0
# 5     40.0      55.0
# 6     45.0      55.0
# 7     58.0      55.0
# 8     90.0      90.0

# %%
dfstd.fillna(method = "bfill")
# Out:
#    English  Science
# 0     50.0      40.0
# 1     40.0      45.0
# 2     40.0      58.0
# 3     40.0      90.0
# 4     40.0      55.0
# 5     40.0      90.0
# 6     45.0      90.0
# 7     58.0      90.0
# 8     90.0      90.0

# %%
dfstd.fillna(method = "ffill", limit = 2, inplace = True)

# %%
dfstd
# Out:
#    English  Science
# 0     50.0      40.0
# 1     50.0      45.0
# 2     50.0      58.0
# 3      NaN      90.0
# 4      NaN      55.0
# 5     40.0      55.0
# 6     45.0      55.0
# 7     58.0       NaN
# 8     90.0      90.0

# %%
dfstd.fillna(method = "bfill", limit = 2)
# Out:
#    English  Science
# 0     50.0      40.0
# 1     50.0      45.0
# 2     50.0      58.0
# 3     40.0      90.0
# 4     40.0      55.0
# 5     40.0      55.0
# 6     45.0      55.0
# 7     58.0      90.0
# 8     90.0      90.0

# %%
dfhyd = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\hyd_temp.csv")

# %%
dfhyd
# Out:
#         Date  Hyderabad  Humid
# 0   1-Feb-22       35.0   40.0
# 1   2-Feb-22        NaN   44.0
# 2   3-Feb-22       36.0    NaN
# 3   4-Feb-22       32.0   41.0
# 4   5-Feb-22       28.0   35.0
# 5   6-Feb-22       32.0    NaN
# 6   7-Feb-22       22.0   50.0
# 7   8-Feb-22        NaN   42.0
# 8  19-Feb-22       35.0   43.0

# %%
dfhyd.interpolate()
# Out:
#         Date  Hyderabad  Humid
# 0   1-Feb-22       35.0   40.0
# 1   2-Feb-22       35.5   44.0
# 2   3-Feb-22       36.0   42.5
# 3   4-Feb-22       32.0   41.0
# 4   5-Feb-22       28.0   35.0
# 5   6-Feb-22       32.0   42.5
# 6   7-Feb-22       22.0   50.0
# 7   8-Feb-22       28.5   42.0
# 8  19-Feb-22       35.0   43.0

# %%
dfhyd.interpolate(method = 'linear')
# Out:
#         Date  Hyderabad  Humid
# 0   1-Feb-22       35.0   40.0
# 1   2-Feb-22       35.5   44.0
# 2   3-Feb-22       36.0   42.5
# 3   4-Feb-22       32.0   41.0
# 4   5-Feb-22       28.0   35.0
# 5   6-Feb-22       32.0   42.5
# 6   7-Feb-22       22.0   50.0
# 7   8-Feb-22       28.5   42.0
# 8  19-Feb-22       35.0   43.0

# %%
dfhyd["Date"]
# Out:
# 0     1-Feb-22
# 1     2-Feb-22
# 2     3-Feb-22
# 3     4-Feb-22
# 4     5-Feb-22
# 5     6-Feb-22
# 6     7-Feb-22
# 7     8-Feb-22
# 8    19-Feb-22
# Name: Date, dtype: object

# %%
type(dfhyd["Date"])
# Out:
# pandas.core.series.Series

# %%
dfhyd["Date"][0]
# Out:
# '1-Feb-22'

# %%
type(dfhyd["Date"][0])
# Out:
# str

# %%
pd.to_datetime(dfhyd["Date"][0])
# Out:
# Timestamp('2022-02-01 00:00:00')

# %%
dfhyd["Date"][0]
# Out:
# '1-Feb-22'

# %%
a = pd.to_datetime(dfhyd["Date"][0])

# %%
a
# Out:
# Timestamp('2022-02-01 00:00:00')

# %%
dfhyd["Date"]
# Out:
# 0     1-Feb-22
# 1     2-Feb-22
# 2     3-Feb-22
# 3     4-Feb-22
# 4     5-Feb-22
# 5     6-Feb-22
# 6     7-Feb-22
# 7     8-Feb-22
# 8    19-Feb-22
# Name: Date, dtype: object

# %%
pd.to_datetime(dfhyd["Date"])
# Out:
# 0   2022-02-01
# 1   2022-02-02
# 2   2022-02-03
# 3   2022-02-04
# 4   2022-02-05
# 5   2022-02-06
# 6   2022-02-07
# 7   2022-02-08
# 8   2022-02-19
# Name: Date, dtype: datetime64[ns]
