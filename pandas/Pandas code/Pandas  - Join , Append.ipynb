# %%
import pandas as pd
import numpy as np

# %%
d5= {
    
    "SCity" :["Vizag","Chennai", "Hyderabad","Bangalore"],
    "Temp" : [34,38,33,36]

    
    
}



d6 = {
    
    "NCity" :["Delhi", "Mumbai","Pune", "Jaipur"],
    "Humid" : [40,43,42,40]
    
    
}

dfdic5 = pd.DataFrame(d5)
dfdic6 = pd.DataFrame(d6)

# %%
dfdic5 = pd.DataFrame(d5)
dfdic6 = pd.DataFrame(d6)

# %%
dfdic5
# Out:
#        SCity  Temp
# 0      Vizag    34
# 1    Chennai    38
# 2  Hyderabad    33
# 3  Bangalore    36

# %%
dfdic6
# Out:
#     NCity  Humid
# 0   Delhi     40
# 1  Mumbai     43
# 2    Pune     42
# 3  Jaipur     40

# %%
pd.concat([dfdic5, dfdic6])
# Out:
#        SCity  Temp   NCity  Humid
# 0      Vizag  34.0     NaN    NaN
# 1    Chennai  38.0     NaN    NaN
# 2  Hyderabad  33.0     NaN    NaN
# 3  Bangalore  36.0     NaN    NaN
# 0        NaN   NaN   Delhi   40.0
# 1        NaN   NaN  Mumbai   43.0
# 2        NaN   NaN    Pune   42.0
# 3        NaN   NaN  Jaipur   40.0

# %%
pd.concat([dfdic5, dfdic6], axis = 1)
# Out:
#        SCity  Temp   NCity  Humid
# 0      Vizag    34   Delhi     40
# 1    Chennai    38  Mumbai     43
# 2  Hyderabad    33    Pune     42
# 3  Bangalore    36  Jaipur     40

# %%
dfdic5.join(dfdic6)
# Out:
#        SCity  Temp   NCity  Humid
# 0      Vizag    34   Delhi     40
# 1    Chennai    38  Mumbai     43
# 2  Hyderabad    33    Pune     42
# 3  Bangalore    36  Jaipur     40

# %%
d7= {
    
    "City" :["Vizag","Chennai", "Hyderabad","Bangalore"],
    "Temp" : [34,38,33,36]

    
    
}



d8 = {
    
    "City" :["Delhi", "Mumbai","Pune", "Jaipur"],
    "Humid" : [40,43,42,40]
    
    
}

dfdic7 = pd.DataFrame(d7)
dfdic8 = pd.DataFrame(d8)

# %%
display(dfdic7, dfdic8)
# Out:
#         City  Temp
# 0      Vizag    34
# 1    Chennai    38
# 2  Hyderabad    33
# 3  Bangalore    36
#      City  Humid
# 0   Delhi     40
# 1  Mumbai     43
# 2    Pune     42
# 3  Jaipur     40

# %%
pd.concat([dfdic7, dfdic8], axis = 1)
# Out:
#         City  Temp    City  Humid
# 0      Vizag    34   Delhi     40
# 1    Chennai    38  Mumbai     43
# 2  Hyderabad    33    Pune     42
# 3  Bangalore    36  Jaipur     40

# %%
dfdic7.join(dfdic8, lsuffix="_left")
# Out:
#    City_left  Temp    City  Humid
# 0      Vizag    34   Delhi     40
# 1    Chennai    38  Mumbai     43
# 2  Hyderabad    33    Pune     42
# 3  Bangalore    36  Jaipur     40

# %%
dfdic7.join(dfdic8, rsuffix="_right")
# Out:
#         City  Temp City_right  Humid
# 0      Vizag    34      Delhi     40
# 1    Chennai    38     Mumbai     43
# 2  Hyderabad    33       Pune     42
# 3  Bangalore    36     Jaipur     40

# %% [markdown]
# ### PANDAS APPEND

# %%
d3 = {
    
    "City" :["Vizag","Chennai", "Hyderabad","Bangalore"],
    "Temp" : [34,38,33,36],

    
    
}



d4 = {
    
    "City" :["DELHI","JAIPUR", "LUCKNOW","BHOPAL"],
    "Temp" : [40,43,42,40]
    
    
}

dfdic3 = pd.DataFrame(d3)
dfdic4 = pd.DataFrame(d4)

# %%
display(dfdic3, dfdic4)
# Out:
#         City  Temp
# 0      Vizag    34
# 1    Chennai    38
# 2  Hyderabad    33
# 3  Bangalore    36
#       City  Temp
# 0    DELHI    40
# 1   JAIPUR    43
# 2  LUCKNOW    42
# 3   BHOPAL    40

# %%
dfresult = pd.concat([dfdic3, dfdic4])

# %%
dfresult.iloc[0]
# Out:
#         City  Temp
# 0      Vizag    34
# 1    Chennai    38
# 2  Hyderabad    33
# 3  Bangalore    36
# 0      DELHI    40
# 1     JAIPUR    43
# 2    LUCKNOW    42
# 3     BHOPAL    40

# %%
dfresult.iloc[0]
# Out:
# City    Vizag
# Temp       34
# Name: 0, dtype: object

# %%
dfresult.loc[0]
# Out:
#     City  Temp
# 0  Vizag    34
# 0  DELHI    40

# %%
dfdic3.append(dfdic4)
# Out:
#         City  Temp
# 0      Vizag    34
# 1    Chennai    38
# 2  Hyderabad    33
# 3  Bangalore    36
# 0      DELHI    40
# 1     JAIPUR    43
# 2    LUCKNOW    42
# 3     BHOPAL    40

# %%
dfdic3.append(dfdic4, ignore_index = True)
# Out:
#         City  Temp
# 0      Vizag    34
# 1    Chennai    38
# 2  Hyderabad    33
# 3  Bangalore    36
# 4      DELHI    40
# 5     JAIPUR    43
# 6    LUCKNOW    42
# 7     BHOPAL    40
