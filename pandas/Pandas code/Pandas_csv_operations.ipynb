# %%
import pandas as pd

# %%
dfstd = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\std_data1.csv")

# %%
dfstd
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
dfstd.columns
# Out:
# Index(['SNAME', 'SCLASS ', 'ENGLISH', 'COMPUTER', 'SCIENCE'], dtype='object')

# %%
dfstd.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
dfstd.head()
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56

# %%
dfstd.tail()
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
dfcountry = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\world.csv")

# %%
dfcountry
# Out:
#                        company  rank  rank_change   revenue   profit  \
# 0                      Walmart     1            0  523964.0  14881.0
# 1                       Amazon     2            3  280522.0  11588.0
# 2                  Exxon Mobil     3           -1  264938.0  14340.0
# 3                        Apple     4           -1  260174.0  55256.0
# 4                   CVS Health     5            3  256776.0   6634.0
# ..                         ...   ...          ...       ...      ...
# 995           Mr. Cooper Group   996            0    2007.0    274.0
# 996              Herc Holdings   997            0    1999.0     47.5
# 997      Healthpeak Properties   998            0    1997.4     45.5
# 998                   SPX FLOW   999            0    1996.3    -95.1
# 999  Liberty Oilfield Services  1000            0    1990.3     39.0
#
#      num. of employees             sector            city state prev_rank  \
# ...

# %%
dfcountry.head(10)
# Out:
#               company  rank  rank_change   revenue   profit  \
# 0             Walmart     1            0  523964.0  14881.0
# 1              Amazon     2            3  280522.0  11588.0
# 2         Exxon Mobil     3           -1  264938.0  14340.0
# 3               Apple     4           -1  260174.0  55256.0
# 4          CVS Health     5            3  256776.0   6634.0
# 5  Berkshire Hathaway     6           -2  254616.0  81417.0
# 6  UnitedHealth Group     7           -1  242155.0  13839.0
# 7            McKesson     8           -1  214319.0     34.0
# 8                AT&T     9            0  181193.0  13903.0
# 9   AmerisourceBergen    10            0  179589.1    855.4
#
#    num. of employees              sector          city state prev_rank Ticker  \
# 0            2200000           Retailing   Bentonville    AR         1    WMT
# 1             798000           Retailing       Seattle    WA         5   AMZN
# ...

# %%
dfcountry.tail(10)
# Out:
#                        company  rank  rank_change  revenue  profit  \
# 990      Hovnanian Enterprises   991            0   2016.9   -42.1
# 991                  Air Lease   992            0   2016.9   587.1
# 992                    Rollins   993            0   2015.5   203.3
# 993         SBA Communications   994            0   2014.6   147.0
# 994                     Deluxe   995            0   2008.7  -199.9
# 995           Mr. Cooper Group   996            0   2007.0   274.0
# 996              Herc Holdings   997            0   1999.0    47.5
# 997      Healthpeak Properties   998            0   1997.4    45.5
# 998                   SPX FLOW   999            0   1996.3   -95.1
# 999  Liberty Oilfield Services  1000            0   1990.3    39.0
#
#      num. of employees                      sector            city state  \
# 990               1868  Engineering & Construction         Matawan    NJ
# 991                117           Business Services     Los Angeles    CA
# ...

# %%
dfcountry.sample()
# Out:
#                   company  rank  rank_change  revenue  profit  \
# 258  Edison International   259           -4  12347.0  1284.0
#
#      num. of employees  sector      city state prev_rank Ticker Market Cap
# 258              12937  Energy  Rosemead    CA       255    EIX    19867.6

# %%
dfcountry.sample()
# Out:
#    company  rank  rank_change  revenue  profit  num. of employees     sector  \
# 36  Target    37            2  78112.0  3281.0             368000  Retailing
#
#            city state prev_rank Ticker Market Cap
# 36  Minneapolis    MN        39    TGT      94296

# %%
dfcountry.sample(10)
# Out:
#                             company  rank  rank_change  revenue  profit  \
# 788               Boston Properties   789            0   2960.6   521.5
# 489                Realogy Holdings   490          -12   5870.0  -188.0
# 847                          Cooper   848            0   2653.4   466.7
# 632          Allegheny Technologies   633            0   4122.5   257.6
# 37                              IBM    38            0  77147.0  9431.0
# 193  Cognizant Technology Solutions   194           -1  16783.0  1842.0
# 799                            Moog   800            0   2904.7   179.7
# 659            Lennox International   660            0   3807.2   408.7
# 507               RPM International   508            0   5564.6   266.6
# 402              Motorola Solutions   403           13   7887.0   868.0
#
#      num. of employees               sector         city state prev_rank  \
# 788                760           Financials       Boston    MA
# ...

# %%
dfcountry["state"]
# Out:
# 0      AR
# 1      WA
# 2      TX
# 3      CA
# 4      RI
#        ..
# 995    TX
# 996    FL
# 997    CA
# 998    NC
# 999    CO
# Name: state, Length: 1000, dtype: object

# %%
dfcountry["state"].unique()
# Out:
# array(['AR', 'WA', 'TX', 'CA', 'RI', 'NE', 'MN', 'PA', 'MI', 'CT', 'OH',
#        'NY', 'IL', 'DC', 'NC', 'GA', 'IN', 'MA', 'NJ', 'VA', 'MO', 'TN',
#        'KY', 'ID', 'MD', 'OR', 'FL', 'WI', 'CO', 'OK', 'LA', 'DE', 'AZ',
#        'IA', 'NV', 'KS', 'AL', 'SC', 'ND', 'NH', 'MS', 'PR', 'UT', 'HI',
#        'VT', 'ME'], dtype=object)

# %%
dfcountry["state"].unique().size
# Out:
# 46

# %%
dfcountry["sector"]
# Out:
# 0              Retailing
# 1              Retailing
# 2                 Energy
# 3             Technology
# 4            Health Care
#              ...
# 995           Financials
# 996    Business Services
# 997           Financials
# 998          Industrials
# 999               Energy
# Name: sector, Length: 1000, dtype: object

# %%
dfcountry["sector"].unique()
# Out:
# array(['Retailing', 'Energy', 'Technology', 'Health Care', 'Financials',
#        'Telecommunications', 'Motor Vehicles & Parts',
#        'Food & Drug Stores', 'Industrials', 'Aerospace & Defense',
#        'Transportation', 'Media', 'Household Products',
#        'Food, Beverages & Tobacco', 'Wholesalers', 'Chemicals', 'Apparel',
#        'Hotels, Restaurants & Leisure', 'Business Services', 'Materials',
#        'Engineering & Construction'], dtype=object)

# %%
dfcountry["sector"].unique().size
# Out:
# 21

# %%
dfcountry["sector"].value_counts()
# Out:
# Financials                       162
# Technology                       109
# Energy                           109
# Retailing                         75
# Health Care                       71
# Business Services                 52
# Industrials                       50
# Materials                         46
# Transportation                    38
# Food, Beverages & Tobacco         37
# Wholesalers                       35
# Engineering & Construction        30
# Chemicals                         27
# Hotels, Restaurants & Leisure     27
# Household Products                26
# Media                             25
# Aerospace & Defense               22
# Motor Vehicles & Parts            22
# Apparel                           16
# Telecommunications                11
# Food & Drug Stores                10
# Name: sector, dtype: int64

# %%
dfcountry
# Out:
#                        company  rank  rank_change   revenue   profit  \
# 0                      Walmart     1            0  523964.0  14881.0
# 1                       Amazon     2            3  280522.0  11588.0
# 2                  Exxon Mobil     3           -1  264938.0  14340.0
# 3                        Apple     4           -1  260174.0  55256.0
# 4                   CVS Health     5            3  256776.0   6634.0
# ..                         ...   ...          ...       ...      ...
# 995           Mr. Cooper Group   996            0    2007.0    274.0
# 996              Herc Holdings   997            0    1999.0     47.5
# 997      Healthpeak Properties   998            0    1997.4     45.5
# 998                   SPX FLOW   999            0    1996.3    -95.1
# 999  Liberty Oilfield Services  1000            0    1990.3     39.0
#
#      num. of employees             sector            city state prev_rank  \
# ...

# %%
dfcountry["state"].unique().size
# Out:
# 46

# %%
dfcountry["state"].value_counts()
# Out:
# CA    121
# TX     95
# NY     89
# IL     65
# OH     53
# PA     44
# FL     38
# VA     35
# GA     34
# MA     33
# NC     31
# MI     29
# NJ     27
# CT     25
# MN     24
# WI     23
# CO     23
# MO     20
# TN     20
# AZ     19
# IN     18
# WA     16
# MD     13
# OK     12
# NV      9
# NE      8
# AR      8
# KY      7
# RI      7
# IA      6
# OR      6
# DE      6
# KS      4
# ID      4
# LA      4
# DC      4
# AL      3
# SC      3
# UT      3
# HI      3
# NH      2
# PR      2
# ND      1
# MS      1
# VT      1
# ME      1
# Name: state, dtype: int64

# %%
dfcountry.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   company            1000 non-null   object
#  1   rank               1000 non-null   int64
#  2   rank_change        1000 non-null   int64
#  3   revenue            1000 non-null   float64
#  4   profit             998 non-null    float64
#  5   num. of employees  1000 non-null   int64
#  6   sector             1000 non-null   object
#  7   city               1000 non-null   object
#  8   state              1000 non-null   object
#  9   prev_rank          1000 non-null   object
#  10  Ticker             938 non-null    object
#  11  Market Cap         960 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 93.9+ KB

# %%
dfcountry.describe()
# Out:
#               rank  rank_change        revenue        profit  \
# count  1000.000000  1000.000000    1000.000000    998.000000
# mean    500.497000     0.426000   15902.339000   1344.702806
# std     288.820278    22.424169   34762.973179   4515.839383
# min       1.000000  -186.000000    1990.300000  -8506.000000
# 25%     250.750000     0.000000    3164.200000    110.650000
# 50%     500.500000     0.000000    5647.000000    380.700000
# 75%     750.250000     0.000000   12819.775000   1061.075000
# max    1000.000000   224.000000  523964.000000  81417.000000
#
#        num. of employees
# count       1.000000e+03
# mean        3.461598e+04
# std         9.202401e+04
# min         5.100000e+01
# 25%         6.400000e+03
# 50%         1.300000e+04
# 75%         2.919200e+04
# max         2.200000e+06

# %%
dfstd1 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\std_data2.csv", header=1)

# %%
dfstd1
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
dfstd2 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\std_data2.csv", skiprows=1)

# %%
dfstd2
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
dfstd2 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\std_data1.csv", skiprows=[2, 4, 6])

# %%
dfstd2
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     C       11       66        89       63
# 2     E       10       89        90       56
# 3     G       12       90        83       88
# 4     H       11       79        88       90

# %%
dfcountry
# Out:
#                        company  rank  rank_change   revenue   profit  \
# 0                      Walmart     1            0  523964.0  14881.0
# 1                       Amazon     2            3  280522.0  11588.0
# 2                  Exxon Mobil     3           -1  264938.0  14340.0
# 3                        Apple     4           -1  260174.0  55256.0
# 4                   CVS Health     5            3  256776.0   6634.0
# ..                         ...   ...          ...       ...      ...
# 995           Mr. Cooper Group   996            0    2007.0    274.0
# 996              Herc Holdings   997            0    1999.0     47.5
# 997      Healthpeak Properties   998            0    1997.4     45.5
# 998                   SPX FLOW   999            0    1996.3    -95.1
# 999  Liberty Oilfield Services  1000            0    1990.3     39.0
#
#      num. of employees             sector            city state prev_rank  \
# ...

# %%
dfcountry2 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\world.csv", nrows= 50)

# %%
dfcountry2
# Out:
#                      company  rank  rank_change   revenue   profit  \
# 0                    Walmart     1            0  523964.0  14881.0
# 1                     Amazon     2            3  280522.0  11588.0
# 2                Exxon Mobil     3           -1  264938.0  14340.0
# 3                      Apple     4           -1  260174.0  55256.0
# 4                 CVS Health     5            3  256776.0   6634.0
# 5         Berkshire Hathaway     6           -2  254616.0  81417.0
# 6         UnitedHealth Group     7           -1  242155.0  13839.0
# 7                   McKesson     8           -1  214319.0     34.0
# 8                       AT&T     9            0  181193.0  13903.0
# 9          AmerisourceBergen    10            0  179589.1    855.4
# 10                  Alphabet    11            4  161857.0  34343.0
# 11                Ford Motor    12            0  155900.0     47.0
# 12                     Cigna    13           52  153566.0   5104.0
# ...

# %%
dfcountry.sample(50)
# Out:
#                              company  rank  rank_change  revenue   profit  \
# 747        Crestwood Equity Partners   748            0   3181.9    285.1
# 651                             ASGN   652            0   3923.9    174.7
# 519        Jefferies Financial Group   520            0   5358.7    964.7
# 593                  Ryerson Holding   594            0   4501.6     82.4
# 924    Alpha Metallurgical Resources   925            0   2290.5   -316.3
# 819                          Popular   820            0   2830.7    671.1
# 201                      Ross Stores   202            7  16039.1   1660.9
# 749                           Plexus   750            0   3164.4    108.6
# 728               LSC Communications   729            0   3326.0   -295.0
# 639             Wyndham Destinations   640            0   4043.0    507.0
# 317                       News Corp.   318           23  10074.0    155.0
# 736                         Autodesk   737            0   3274.3    214.5
# ...

# %%
dfstd2
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     C       11       66        89       63
# 2     E       10       89        90       56
# 3     G       12       90        83       88
# 4     H       11       79        88       90

# %%
dfstd3 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\std_data1.csv", usecols=["SNAME", "COMPUTER"])
dfstd3
# Out:
#   SNAME  COMPUTER
# 0     A        66
# 1     B        56
# 2     C        89
# 3     D        88
# 4     E        90
# 5     F        85
# 6     G        83
# 7     H        88

# %%
dfstd3 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\std_data1.csv", usecols=[0,2,3,4])
dfstd3
# Out:
#   SNAME  ENGLISH  COMPUTER  SCIENCE
# 0     A       67        66       66
# 1     B       87        56       65
# 2     C       66        89       63
# 3     D       56        88       66
# 4     E       89        90       56
# 5     F       88        85       89
# 6     G       90        83       88
# 7     H       79        88       90

# %%
dfstd3.index = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']

# %%
list("ABCDEFGH")
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']

# %%
dfstd3
# Out:
#   SNAME  ENGLISH  COMPUTER  SCIENCE
# A     A       67        66       66
# B     B       87        56       65
# C     C       66        89       63
# D     D       56        88       66
# E     E       89        90       56
# F     F       88        85       89
# G     G       90        83       88
# H     H       79        88       90

# %%
dfstd3.set_index("ENGLISH")
# Out:
#         SNAME  COMPUTER  SCIENCE
# ENGLISH
# 67          A        66       66
# 87          B        56       65
# 66          C        89       63
# 56          D        88       66
# 89          E        90       56
# 88          F        85       89
# 90          G        83       88
# 79          H        88       90

# %%
dfstd4 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\std_data1.csv", index_col=["ENGLISH"])

# %%
dfstd4
# Out:
#         SNAME  SCLASS   COMPUTER  SCIENCE
# ENGLISH
# 67          A       10        66       66
# 87          B       12        56       65
# 66          C       11        89       63
# 56          D       10        88       66
# 89          E       10        90       56
# 88          F        9        85       89
# 90          G       12        83       88
# 79          H       11        88       90

# %%
dfstd5 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\std_data3.csv", header = None, prefix = "Cols")
dfstd5
# Out:
#   Cols0  Cols1  Cols2  Cols3  Cols4
# 0     A     10     67     66     66
# 1     B     12     87     56     65
# 2     C     11     66     89     63
# 3     D     10     56     88     66
# 4     E     10     89     90     56
# 5     F      9     88     85     89
# 6     G     12     90     83     88
# 7     H     11     79     88     90

# %%
dfstd6 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\std_data3.csv", names= ["STDNAME","STDCLASS","ENGLISH","COMPUTERS","SCIENCE"])
dfstd6
# Out:
#   STDNAME  STDCLASS  ENGLISH  COMPUTERS  SCIENCE
# 0       A        10       67         66       66
# 1       B        12       87         56       65
# 2       C        11       66         89       63
# 3       D        10       56         88       66
# 4       E        10       89         90       56
# 5       F         9       88         85       89
# 6       G        12       90         83       88
# 7       H        11       79         88       90

# %%
pd.read_csv()

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
dfcountry
# Out:
#                        company  rank  rank_change   revenue   profit  \
# 0                      Walmart     1            0  523964.0  14881.0
# 1                       Amazon     2            3  280522.0  11588.0
# 2                  Exxon Mobil     3           -1  264938.0  14340.0
# 3                        Apple     4           -1  260174.0  55256.0
# 4                   CVS Health     5            3  256776.0   6634.0
# ..                         ...   ...          ...       ...      ...
# 995           Mr. Cooper Group   996            0    2007.0    274.0
# 996              Herc Holdings   997            0    1999.0     47.5
# 997      Healthpeak Properties   998            0    1997.4     45.5
# 998                   SPX FLOW   999            0    1996.3    -95.1
# 999  Liberty Oilfield Services  1000            0    1990.3     39.0
#
#      num. of employees             sector            city state prev_rank  \
# ...

# %%
dfcountry3 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\world.csv", nrows= 200)

# %%
dfcountry3
# Out:
#              company  rank  rank_change   revenue   profit  num. of employees  \
# 0            Walmart     1            0  523964.0  14881.0            2200000
# 1             Amazon     2            3  280522.0  11588.0             798000
# 2        Exxon Mobil     3           -1  264938.0  14340.0              74900
# 3              Apple     4           -1  260174.0  55256.0             137000
# 4         CVS Health     5            3  256776.0   6634.0             290000
# ..               ...   ...          ...       ...      ...                ...
# 195    XPO Logistics   196          -16   16648.0    419.0             100000
# 196  Dominion Energy   197           41   16572.0   1358.0              19100
# 197  Western Digital   198          -46   16569.0   -754.0              61800
# 198              Gap   199          -13   16383.0    351.0             129000
# 199          Aramark   200           -2   16227.3    448.5             233400
#
# ...

# %%
pd.select_option()

# %%
pd.option_context('display.max_rows', 200)
dfcountry3
# Out:
#              company  rank  rank_change   revenue   profit  num. of employees  \
# 0            Walmart     1            0  523964.0  14881.0            2200000
# 1             Amazon     2            3  280522.0  11588.0             798000
# 2        Exxon Mobil     3           -1  264938.0  14340.0              74900
# 3              Apple     4           -1  260174.0  55256.0             137000
# 4         CVS Health     5            3  256776.0   6634.0             290000
# ..               ...   ...          ...       ...      ...                ...
# 195    XPO Logistics   196          -16   16648.0    419.0             100000
# 196  Dominion Energy   197           41   16572.0   1358.0              19100
# 197  Western Digital   198          -46   16569.0   -754.0              61800
# 198              Gap   199          -13   16383.0    351.0             129000
# 199          Aramark   200           -2   16227.3    448.5             233400
#
# ...

# %%
pd.set_option("display.max_rows", None)

# %%
dfcountry3
# Out:
#                                company  rank  rank_change   revenue   profit  \
# 0                              Walmart     1            0  523964.0  14881.0
# 1                               Amazon     2            3  280522.0  11588.0
# 2                          Exxon Mobil     3           -1  264938.0  14340.0
# 3                                Apple     4           -1  260174.0  55256.0
# 4                           CVS Health     5            3  256776.0   6634.0
# 5                   Berkshire Hathaway     6           -2  254616.0  81417.0
# 6                   UnitedHealth Group     7           -1  242155.0  13839.0
# 7                             McKesson     8           -1  214319.0     34.0
# 8                                 AT&T     9            0  181193.0  13903.0
# 9                    AmerisourceBergen    10            0  179589.1    855.4
# 10                            Alphabet    11            4  161857.0  34343.0
# ...

# %%
dfstd
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
dfstd.dtypes
# Out:
# SNAME       object
# SCLASS       int64
# ENGLISH      int64
# COMPUTER     int64
# SCIENCE      int64
# dtype: object

# %%
import numpy as np
dfstd["ENGLISH"].astype(np.float64)
# Out:
# 0    67.0
# 1    87.0
# 2    66.0
# 3    56.0
# 4    89.0
# 5    88.0
# 6    90.0
# 7    79.0
# Name: ENGLISH, dtype: float64

# %%
dfstd8 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\std_data3.csv", na_values=[830,999,"TEN"],
                     names= ["STDNAME","STDCLASS","ENGLISH","COMPUTERS","SCIENCE"])

# %%
dfstd8
# Out:
#   STDNAME  STDCLASS  ENGLISH  COMPUTERS  SCIENCE
# 0       A      10.0     67.0       66.0     66.0
# 1       B      12.0     87.0       56.0      NaN
# 2       C      11.0      NaN       89.0     63.0
# 3       D       NaN     56.0       88.0      NaN
# 4       E      10.0     89.0        NaN     56.0
# 5       F       9.0     88.0       85.0     89.0
# 6       G      12.0      NaN        NaN      NaN
# 7       H      11.0     79.0       88.0     90.0

# %%
d1 = {
    
    "Hyderabad" : [0],
    "DELHI" : [-2,2],
    "SRINAGAR" : [30]
}

# %%
d1
# Out:
# {'Hyderabad': [0], 'DELHI': [-2, 2], 'SRINAGAR': [30]}

# %%
dftemp1 = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\temp.csv",na_values = d1 )

# %%
dftemp
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0         35     36         0
# 1         30     -2        -1
# 2         36     28        -3
# 3          0     32        -2
# 4         28      2         2
# 5         32     30        30

# %%
dftemp1
# Out:
#    Hyderabad  DELHI  SRINAGAR
# 0       35.0   36.0       0.0
# 1       30.0    NaN      -1.0
# 2       36.0   28.0      -3.0
# 3        NaN   32.0      -2.0
# 4       28.0    NaN       2.0
# 5       32.0   30.0       NaN
