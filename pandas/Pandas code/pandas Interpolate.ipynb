# %%
import pandas as pd
import numpy as np

# %%
dfstd = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\Interpolate\\std_multinan.csv")

# %%
dfstd
# Out:
#   Name  English  Science
# 0  AAA     50.0      40.0
# 1  BBB      NaN      45.0
# 2  CCC      NaN      58.0
# 3  DDD      NaN      90.0
# 4  EEE      NaN      55.0
# 5  NaN     40.0       NaN
# 6  GGG     45.0       NaN
# 7  NaN     58.0       NaN
# 8  KKK     90.0      90.0

# %%
dfstd.fillna(method = "ffill")
# Out:
#   Name  English  Science
# 0  AAA     50.0      40.0
# 1  BBB     50.0      45.0
# 2  CCC     50.0      58.0
# 3  DDD     50.0      90.0
# 4  EEE     50.0      55.0
# 5  EEE     40.0      55.0
# 6  GGG     45.0      55.0
# 7  GGG     58.0      55.0
# 8  KKK     90.0      90.0

# %%
dfstd.interpolate()
# Out:
#   Name  English  Science
# 0  AAA     50.0     40.00
# 1  BBB     48.0     45.00
# 2  CCC     46.0     58.00
# 3  DDD     44.0     90.00
# 4  EEE     42.0     55.00
# 5  NaN     40.0     63.75
# 6  GGG     45.0     72.50
# 7  NaN     58.0     81.25
# 8  KKK     90.0     90.00

# %%
dfstd
# Out:
#   Name  English  Science
# 0  AAA     50.0      40.0
# 1  BBB      NaN      45.0
# 2  CCC      NaN      58.0
# 3  DDD      NaN      90.0
# 4  EEE      NaN      55.0
# 5  NaN     40.0       NaN
# 6  GGG     45.0       NaN
# 7  NaN     58.0       NaN
# 8  KKK     90.0      90.0

# %%
dfstd.interpolate(method = 'nearest')
# Out:
#   Name  English  Science
# 0  AAA     50.0      40.0
# 1  BBB     50.0      45.0
# 2  CCC     50.0      58.0
# 3  DDD     40.0      90.0
# 4  EEE     40.0      55.0
# 5  NaN     40.0      55.0
# 6  GGG     45.0      55.0
# 7  NaN     58.0      90.0
# 8  KKK     90.0      90.0

# %% [markdown]
# ### INTERPOLATE - INDEX

# %%
dfstdage = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\Interpolate\\std_interp.csv")

# %%
dfstdage
# Out:
#   Stdname  StdClass   Age
# 0     AAA        10  15.0
# 1     BBB        11   NaN
# 2     CCC        12  18.0
# 3     DDD        10   NaN
# 4     EEE        11  16.0
# 5     FFF        12  18.0
# 6     GGG        11  16.0
# 7     HHH        10  15.0
# 8     JJJ        12   NaN
# 9     KKK        10   NaN

# %%
dfstdage.interpolate()
# Out:
#   Stdname  StdClass   Age
# 0     AAA        10  15.0
# 1     BBB        11  16.5
# 2     CCC        12  18.0
# 3     DDD        10  17.0
# 4     EEE        11  16.0
# 5     FFF        12  18.0
# 6     GGG        11  16.0
# 7     HHH        10  15.0
# 8     JJJ        12  15.0
# 9     KKK        10  15.0

# %%
dfstdage1 = dfstdage.set_index("StdClass")

# %%
dfstdage1
# Out:
#          Stdname   Age
# StdClass
# 10           AAA  15.0
# 11           BBB   NaN
# 12           CCC  18.0
# 10           DDD   NaN
# 11           EEE  16.0
# 12           FFF  18.0
# 11           GGG  16.0
# 10           HHH  15.0
# 12           JJJ   NaN
# 10           KKK   NaN

# %%
dfstdage1.interpolate(method = "index")
# Out:
#          Stdname   Age
# StdClass
# 10           AAA  15.0
# 11           BBB  16.0
# 12           CCC  18.0
# 10           DDD  15.0
# 11           EEE  16.0
# 12           FFF  18.0
# 11           GGG  16.0
# 10           HHH  15.0
# 12           JJJ  18.0
# 10           KKK  15.0

# %%
dfstdage
# Out:
#   Stdname  StdClass   Age
# 0     AAA        10  15.0
# 1     BBB        11   NaN
# 2     CCC        12  18.0
# 3     DDD        10   NaN
# 4     EEE        11  16.0
# 5     FFF        12  18.0
# 6     GGG        11  16.0
# 7     HHH        10  15.0
# 8     JJJ        12   NaN
# 9     KKK        10   NaN

# %%
dfstdage.interpolate(method = 'index')
# Out:
#   Stdname  StdClass   Age
# 0     AAA        10  15.0
# 1     BBB        11  16.5
# 2     CCC        12  18.0
# 3     DDD        10  17.0
# 4     EEE        11  16.0
# 5     FFF        12  18.0
# 6     GGG        11  16.0
# 7     HHH        10  15.0
# 8     JJJ        12  15.0
# 9     KKK        10  15.0

# %%
dfstdtime = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\Interpolate\\temp_interpolate_time.csv")

# %%
dfstdtime
# Out:
#          Date  Temp  DayType
# 0   21-Jan-22  30.0      NaN
# 1   22-Jan-22  32.0      NaN
# 2   23-Jan-22   NaN      NaN
# 3   29-Jan-22  25.0      NaN
# 4   30-Jan-22  26.0      NaN
# 5   31-Jan-22  28.0      NaN
# 6    1-Feb-22  25.0      NaN
# 7   12-Feb-22   NaN      NaN
# 8   13-Feb-22  36.0      NaN
# 9   14-Feb-22  38.0      NaN
# 10  15-Feb-22  36.0      NaN

# %%
dfstdtime.drop("DayType", axis = 1, inplace = True)

# %%
dfstdtime
# Out:
#          Date  Temp
# 0   21-Jan-22  30.0
# 1   22-Jan-22  32.0
# 2   23-Jan-22   NaN
# 3   29-Jan-22  25.0
# 4   30-Jan-22  26.0
# 5   31-Jan-22  28.0
# 6    1-Feb-22  25.0
# 7   12-Feb-22   NaN
# 8   13-Feb-22  36.0
# 9   14-Feb-22  38.0
# 10  15-Feb-22  36.0

# %%
dfstdtime.interpolate()
# Out:
#          Date  Temp
# 0   21-Jan-22  30.0
# 1   22-Jan-22  32.0
# 2   23-Jan-22  28.5
# 3   29-Jan-22  25.0
# 4   30-Jan-22  26.0
# 5   31-Jan-22  28.0
# 6    1-Feb-22  25.0
# 7   12-Feb-22  30.5
# 8   13-Feb-22  36.0
# 9   14-Feb-22  38.0
# 10  15-Feb-22  36.0

# %%
dfstdtime["Date"]
# Out:
# 0     21-Jan-22
# 1     22-Jan-22
# 2     23-Jan-22
# 3     29-Jan-22
# 4     30-Jan-22
# 5     31-Jan-22
# 6      1-Feb-22
# 7     12-Feb-22
# 8     13-Feb-22
# 9     14-Feb-22
# 10    15-Feb-22
# Name: Date, dtype: object

# %%
dfstdtime["Date"][3]
# Out:
# '29-Jan-22'

# %%
type(dfstdtime["Date"][3])
# Out:
# str

# %%
dfstdtime["Date"]
# Out:
# 0     21-Jan-22
# 1     22-Jan-22
# 2     23-Jan-22
# 3     29-Jan-22
# 4     30-Jan-22
# 5     31-Jan-22
# 6      1-Feb-22
# 7     12-Feb-22
# 8     13-Feb-22
# 9     14-Feb-22
# 10    15-Feb-22
# Name: Date, dtype: object

# %%
pd.to_datetime(dfstdtime["Date"])
# Out:
# 0    2022-01-21
# 1    2022-01-22
# 2    2022-01-23
# 3    2022-01-29
# 4    2022-01-30
# 5    2022-01-31
# 6    2022-02-01
# 7    2022-02-12
# 8    2022-02-13
# 9    2022-02-14
# 10   2022-02-15
# Name: Date, dtype: datetime64[ns]

# %%
dfstdtime
# Out:
#          Date  Temp
# 0   21-Jan-22  30.0
# 1   22-Jan-22  32.0
# 2   23-Jan-22   NaN
# 3   29-Jan-22  25.0
# 4   30-Jan-22  26.0
# 5   31-Jan-22  28.0
# 6    1-Feb-22  25.0
# 7   12-Feb-22   NaN
# 8   13-Feb-22  36.0
# 9   14-Feb-22  38.0
# 10  15-Feb-22  36.0

# %%
dfstdtime["Date"] = pd.to_datetime(dfstdtime["Date"])

# %%
dfstdtime
# Out:
#          Date  Temp
# 0  2022-01-21  30.0
# 1  2022-01-22  32.0
# 2  2022-01-23   NaN
# 3  2022-01-29  25.0
# 4  2022-01-30  26.0
# 5  2022-01-31  28.0
# 6  2022-02-01  25.0
# 7  2022-02-12   NaN
# 8  2022-02-13  36.0
# 9  2022-02-14  38.0
# 10 2022-02-15  36.0

# %%
dfstdtime.dtypes
# Out:
# Date    datetime64[ns]
# Temp           float64
# dtype: object

# %%
type( dfstdtime["Date"][5] )
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
dfstdtime = dfstdtime.set_index("Date")

# %%
dfstdtime
# Out:
#             Temp
# Date
# 2022-01-21  30.0
# 2022-01-22  32.0
# 2022-01-23   NaN
# 2022-01-29  25.0
# 2022-01-30  26.0
# 2022-01-31  28.0
# 2022-02-01  25.0
# 2022-02-12   NaN
# 2022-02-13  36.0
# 2022-02-14  38.0
# 2022-02-15  36.0

# %%
dfstdtime.reset_index()
# Out:
#          Date  Temp
# 0  2022-01-21  30.0
# 1  2022-01-22  32.0
# 2  2022-01-23   NaN
# 3  2022-01-29  25.0
# 4  2022-01-30  26.0
# 5  2022-01-31  28.0
# 6  2022-02-01  25.0
# 7  2022-02-12   NaN
# 8  2022-02-13  36.0
# 9  2022-02-14  38.0
# 10 2022-02-15  36.0

# %%
dfstdtime
# Out:
#             Temp
# Date
# 2022-01-21  30.0
# 2022-01-22  32.0
# 2022-01-23   NaN
# 2022-01-29  25.0
# 2022-01-30  26.0
# 2022-01-31  28.0
# 2022-02-01  25.0
# 2022-02-12   NaN
# 2022-02-13  36.0
# 2022-02-14  38.0
# 2022-02-15  36.0

# %%
dfstdtime.interpolate(method = 'time')
# Out:
#                  Temp
# Date
# 2022-01-21  30.000000
# 2022-01-22  32.000000
# 2022-01-23  31.000000
# 2022-01-29  25.000000
# 2022-01-30  26.000000
# 2022-01-31  28.000000
# 2022-02-01  25.000000
# 2022-02-12  35.083333
# 2022-02-13  36.000000
# 2022-02-14  38.000000
# 2022-02-15  36.000000

# %%
dfstd
# Out:
#   Name  English  Science
# 0  AAA     50.0      40.0
# 1  BBB      NaN      45.0
# 2  CCC      NaN      58.0
# 3  DDD      NaN      90.0
# 4  EEE      NaN      55.0
# 5  NaN     40.0       NaN
# 6  GGG     45.0       NaN
# 7  NaN     58.0       NaN
# 8  KKK     90.0      90.0

# %%
dfstd.interpolate(method = "pad", limit = 1)
# Out:
#   Name  English  Science
# 0  AAA     50.0      40.0
# 1  BBB     50.0      45.0
# 2  CCC      NaN      58.0
# 3  DDD      NaN      90.0
# 4  EEE      NaN      55.0
# 5  EEE     40.0      55.0
# 6  GGG     45.0       NaN
# 7  GGG     58.0       NaN
# 8  KKK     90.0      90.0

# %%
dfstd.interpolate(method = "linear", limit = 1, limit_direction='forward')
# Out:
#   Name  English  Science
# 0  AAA     50.0     40.00
# 1  BBB     48.0     45.00
# 2  CCC      NaN     58.00
# 3  DDD      NaN     90.00
# 4  EEE      NaN     55.00
# 5  NaN     40.0     63.75
# 6  GGG     45.0       NaN
# 7  NaN     58.0       NaN
# 8  KKK     90.0     90.00

# %%
dfstd.interpolate(method = "linear", limit = 2, limit_direction='backward')
# Out:
#   Name  English  Science
# 0  AAA     50.0     40.00
# 1  BBB      NaN     45.00
# 2  CCC      NaN     58.00
# 3  DDD     44.0     90.00
# 4  EEE     42.0     55.00
# 5  NaN     40.0       NaN
# 6  GGG     45.0     72.50
# 7  NaN     58.0     81.25
# 8  KKK     90.0     90.00

# %%
dfstd.interpolate(method = "linear", limit = 1, limit_direction='both')
# Out:
#   Name  English  Science
# 0  AAA     50.0     40.00
# 1  BBB     48.0     45.00
# 2  CCC      NaN     58.00
# 3  DDD      NaN     90.00
# 4  EEE     42.0     55.00
# 5  NaN     40.0     63.75
# 6  GGG     45.0       NaN
# 7  NaN     58.0     81.25
# 8  KKK     90.0     90.00

# %% [markdown]
# #### DROPNA

# %%
dfstdtime
# Out:
#             Temp
# Date
# 2022-01-21  30.0
# 2022-01-22  32.0
# 2022-01-23   NaN
# 2022-01-29  25.0
# 2022-01-30  26.0
# 2022-01-31  28.0
# 2022-02-01  25.0
# 2022-02-12   NaN
# 2022-02-13  36.0
# 2022-02-14  38.0
# 2022-02-15  36.0

# %%
dfstdtime.dropna()
# Out:
#             Temp
# Date
# 2022-01-21  30.0
# 2022-01-22  32.0
# 2022-01-29  25.0
# 2022-01-30  26.0
# 2022-01-31  28.0
# 2022-02-01  25.0
# 2022-02-13  36.0
# 2022-02-14  38.0
# 2022-02-15  36.0

# %%
dfstdtime = dfstdtime.reset_index()

# %%
dfstdtime
# Out:
#          Date  Temp
# 0  2022-01-21  30.0
# 1  2022-01-22  32.0
# 2  2022-01-23   NaN
# 3  2022-01-29  25.0
# 4  2022-01-30  26.0
# 5  2022-01-31  28.0
# 6  2022-02-01  25.0
# 7  2022-02-12   NaN
# 8  2022-02-13  36.0
# 9  2022-02-14  38.0
# 10 2022-02-15  36.0

# %%
dfstdtime.dropna()
# Out:
#          Date  Temp
# 0  2022-01-21  30.0
# 1  2022-01-22  32.0
# 3  2022-01-29  25.0
# 4  2022-01-30  26.0
# 5  2022-01-31  28.0
# 6  2022-02-01  25.0
# 8  2022-02-13  36.0
# 9  2022-02-14  38.0
# 10 2022-02-15  36.0

# %%
dfstd_dp = pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\Interpolate\\std_dropna.csv")

# %%
dfstd_dp
# Out:
#    StdID StdName  Class Location  Total
# 0  111.0       A   10.0      NaN  180.0
# 1    NaN       B    NaN      Viz    NaN
# 2  113.0     NaN   12.0      Blr  150.0
# 3    NaN     NaN    NaN      NaN    NaN
# 4  115.0       E   10.0      Viz    NaN
# 5    NaN       F   11.0      NaN  140.0
# 6  117.0       G    NaN      Hyd  188.0
# 7    NaN     NaN    NaN      NaN    NaN
# 8  119.0     NaN    9.0      Blr    NaN

# %%
dfstd_dp.dropna(how = "all")
# Out:
#    StdID StdName  Class Location  Total
# 0  111.0       A   10.0      NaN  180.0
# 1    NaN       B    NaN      Viz    NaN
# 2  113.0     NaN   12.0      Blr  150.0
# 4  115.0       E   10.0      Viz    NaN
# 5    NaN       F   11.0      NaN  140.0
# 6  117.0       G    NaN      Hyd  188.0
# 8  119.0     NaN    9.0      Blr    NaN

# %%
dfstd_dp
# Out:
#    StdID StdName  Class Location  Total
# 0  111.0       A   10.0      NaN  180.0
# 1    NaN       B    NaN      Viz    NaN
# 2  113.0     NaN   12.0      Blr  150.0
# 3    NaN     NaN    NaN      NaN    NaN
# 4  115.0       E   10.0      Viz    NaN
# 5    NaN       F   11.0      NaN  140.0
# 6  117.0       G    NaN      Hyd  188.0
# 7    NaN     NaN    NaN      NaN    NaN
# 8  119.0     NaN    9.0      Blr    NaN

# %%
dfstd_dp.dropna(thresh=1)
# Out:
#    StdID StdName  Class Location  Total
# 0  111.0       A   10.0      NaN  180.0
# 1    NaN       B    NaN      Viz    NaN
# 2  113.0     NaN   12.0      Blr  150.0
# 4  115.0       E   10.0      Viz    NaN
# 5    NaN       F   11.0      NaN  140.0
# 6  117.0       G    NaN      Hyd  188.0
# 8  119.0     NaN    9.0      Blr    NaN

# %%
dfstd_dp.dropna(thresh=2)
# Out:
#    StdID StdName  Class Location  Total
# 0  111.0       A   10.0      NaN  180.0
# 1    NaN       B    NaN      Viz    NaN
# 2  113.0     NaN   12.0      Blr  150.0
# 4  115.0       E   10.0      Viz    NaN
# 5    NaN       F   11.0      NaN  140.0
# 6  117.0       G    NaN      Hyd  188.0
# 8  119.0     NaN    9.0      Blr    NaN

# %%
dfstd_dp.dropna(thresh=3)
# Out:
#    StdID StdName  Class Location  Total
# 0  111.0       A   10.0      NaN  180.0
# 2  113.0     NaN   12.0      Blr  150.0
# 4  115.0       E   10.0      Viz    NaN
# 5    NaN       F   11.0      NaN  140.0
# 6  117.0       G    NaN      Hyd  188.0
# 8  119.0     NaN    9.0      Blr    NaN

# %%
dfstd_dp
# Out:
#    StdID StdName  Class Location  Total
# 0  111.0       A   10.0      NaN  180.0
# 1    NaN       B    NaN      Viz    NaN
# 2  113.0     NaN   12.0      Blr  150.0
# 3    NaN     NaN    NaN      NaN    NaN
# 4  115.0       E   10.0      Viz    NaN
# 5    NaN       F   11.0      NaN  140.0
# 6  117.0       G    NaN      Hyd  188.0
# 7    NaN     NaN    NaN      NaN    NaN
# 8  119.0     NaN    9.0      Blr    NaN

# %%
dfstd_dp.dropna(thresh=4)
# Out:
#    StdID StdName  Class Location  Total
# 0  111.0       A   10.0      NaN  180.0
# 2  113.0     NaN   12.0      Blr  150.0
# 4  115.0       E   10.0      Viz    NaN
# 6  117.0       G    NaN      Hyd  188.0
