# %%
import pandas as pd
import numpy as np

# %%
df_dset =pd.read_csv("C:\\Users\\Arjun Yadav\\Desktop\\DATASETS\\Dropna\\Dropna_set.csv")

# %%
df_dset.drop("Target Sales Amount", axis = 1, inplace = True)

# %%
df_dset
# Out:
#     Product ID     Product Name  Target   Amount
# 0          111               TV   100.0  45000.0
# 1          222            Table     NaN   5000.0
# 2          333       Dishwasher   100.0      NaN
# 3          444  Washing Machine   100.0  25000.0
# 4          555              NaN   100.0  15000.0
# 5          666     Refrigerator     NaN  30000.0
# 6          777          Blender   100.0      NaN
# 7          888              NaN   100.0   2000.0
# 8          999           Kettle   100.0   1500.0
# 9          112             Iron     NaN   1500.0
# 10         223              NaN   100.0   3000.0
# 11         334             Sofa     NaN   2000.0
# 12         445             Bike   100.0      NaN
# 13         556           Heater   100.0  10000.0
# 14         667              NaN   100.0   8000.0
# 15         778           Mobile     NaN  15000.0
# 16         889           Laptop   100.0  45000.0
# 17         114           Locker   100.0      NaN
# ...

# %%
df_dset.dropna()
# Out:
#     Product ID     Product Name  Target   Amount
# 0          111               TV   100.0  45000.0
# 3          444  Washing Machine   100.0  25000.0
# 8          999           Kettle   100.0   1500.0
# 13         556           Heater   100.0  10000.0
# 16         889           Laptop   100.0  45000.0
# 18         224            Stove   100.0   8000.0

# %%
df_dset.dropna(how = 'all')
# Out:
#     Product ID     Product Name  Target   Amount
# 0          111               TV   100.0  45000.0
# 1          222            Table     NaN   5000.0
# 2          333       Dishwasher   100.0      NaN
# 3          444  Washing Machine   100.0  25000.0
# 4          555              NaN   100.0  15000.0
# 5          666     Refrigerator     NaN  30000.0
# 6          777          Blender   100.0      NaN
# 7          888              NaN   100.0   2000.0
# 8          999           Kettle   100.0   1500.0
# 9          112             Iron     NaN   1500.0
# 10         223              NaN   100.0   3000.0
# 11         334             Sofa     NaN   2000.0
# 12         445             Bike   100.0      NaN
# 13         556           Heater   100.0  10000.0
# 14         667              NaN   100.0   8000.0
# 15         778           Mobile     NaN  15000.0
# 16         889           Laptop   100.0  45000.0
# 17         114           Locker   100.0      NaN
# ...

# %%
df_dset.dropna(how = 'any', axis = 1)
# Out:
#     Product ID
# 0          111
# 1          222
# 2          333
# 3          444
# 4          555
# 5          666
# 6          777
# 7          888
# 8          999
# 9          112
# 10         223
# 11         334
# 12         445
# 13         556
# 14         667
# 15         778
# 16         889
# 17         114
# 18         224

# %%
df_dset
# Out:
#     Product ID     Product Name  Target   Amount
# 0          111               TV   100.0  45000.0
# 1          222            Table     NaN   5000.0
# 2          333       Dishwasher   100.0      NaN
# 3          444  Washing Machine   100.0  25000.0
# 4          555              NaN   100.0  15000.0
# 5          666     Refrigerator     NaN  30000.0
# 6          777          Blender   100.0      NaN
# 7          888              NaN   100.0   2000.0
# 8          999           Kettle   100.0   1500.0
# 9          112             Iron     NaN   1500.0
# 10         223              NaN   100.0   3000.0
# 11         334             Sofa     NaN   2000.0
# 12         445             Bike   100.0      NaN
# 13         556           Heater   100.0  10000.0
# 14         667              NaN   100.0   8000.0
# 15         778           Mobile     NaN  15000.0
# 16         889           Laptop   100.0  45000.0
# 17         114           Locker   100.0      NaN
# ...

# %%
df_dset.dropna(subset = ["Amount"])
# Out:
#     Product ID     Product Name  Target   Amount
# 0          111               TV   100.0  45000.0
# 1          222            Table     NaN   5000.0
# 3          444  Washing Machine   100.0  25000.0
# 4          555              NaN   100.0  15000.0
# 5          666     Refrigerator     NaN  30000.0
# 7          888              NaN   100.0   2000.0
# 8          999           Kettle   100.0   1500.0
# 9          112             Iron     NaN   1500.0
# 10         223              NaN   100.0   3000.0
# 11         334             Sofa     NaN   2000.0
# 13         556           Heater   100.0  10000.0
# 14         667              NaN   100.0   8000.0
# 15         778           Mobile     NaN  15000.0
# 16         889           Laptop   100.0  45000.0
# 18         224            Stove   100.0   8000.0

# %% [markdown]
# ### Pandas CONCAT

# %%
d1 = {
    
    "City" :["Delhi","Jaipur", "Bhopal","Lucknow"],
    "Temp" : [34,38,33,36],
    "Humid" : [40,43,42,40]
    
    
}



d2 = {
    
    "City" :["Vizag","Chennai", "Hyderabad","Bangalore"],
    "Temp" : [34,38,33,36],
    "Humid" : [40,43,42,40]
    
    
}

# %%
dfnorth = pd.DataFrame(d1)
dfsouth = pd.DataFrame(d2)

# %%
dfnorth
# Out:
#       City  Temp  Humid
# 0    Delhi    34     40
# 1   Jaipur    38     43
# 2   Bhopal    33     42
# 3  Lucknow    36     40

# %%
dfsouth
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40

# %%
display(dfsouth, dfnorth)
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40
#       City  Temp  Humid
# 0    Delhi    34     40
# 1   Jaipur    38     43
# 2   Bhopal    33     42
# 3  Lucknow    36     40

# %%
dfind= pd.concat([dfsouth, dfnorth])

# %%
dfind
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40
# 0      Delhi    34     40
# 1     Jaipur    38     43
# 2     Bhopal    33     42
# 3    Lucknow    36     40

# %%
dfind.iloc[4]
# Out:
# City     Delhi
# Temp        34
# Humid       40
# Name: 0, dtype: object

# %%
dfind.loc[0]
# Out:
#     City  Temp  Humid
# 0  Vizag    34     40
# 0  Delhi    34     40

# %%
pd.DataFrame(dfind.iloc[4])
# Out:
#            0
# City   Delhi
# Temp      34
# Humid     40

# %%
dfind1= pd.concat([dfsouth, dfnorth], ignore_index=True)

# %%
dfind1
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40
# 4      Delhi    34     40
# 5     Jaipur    38     43
# 6     Bhopal    33     42
# 7    Lucknow    36     40

# %%
dfind1
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40
# 4      Delhi    34     40
# 5     Jaipur    38     43
# 6     Bhopal    33     42
# 7    Lucknow    36     40

# %%
dfind
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40
# 0      Delhi    34     40
# 1     Jaipur    38     43
# 2     Bhopal    33     42
# 3    Lucknow    36     40

# %%
dfind2= pd.concat([dfsouth, dfnorth], keys=["SOUTH", "NORTH"])

# %%
dfind2
# Out:
#               City  Temp  Humid
# SOUTH 0      Vizag    34     40
#       1    Chennai    38     43
#       2  Hyderabad    33     42
#       3  Bangalore    36     40
# NORTH 0      Delhi    34     40
#       1     Jaipur    38     43
#       2     Bhopal    33     42
#       3    Lucknow    36     40

# %%
dfind2.loc["SOUTH"]
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40

# %%
dfind2.loc["NORTH"]
# Out:
#       City  Temp  Humid
# 0    Delhi    34     40
# 1   Jaipur    38     43
# 2   Bhopal    33     42
# 3  Lucknow    36     40

# %%
dfind2.loc["SOUTH"]
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40

# %%
dfind2.loc["SOUTH"]["Temp"]
# Out:
# 0    34
# 1    38
# 2    33
# 3    36
# Name: Temp, dtype: int64

# %%
dfind2.loc["SOUTH"]["Temp"].mean()
# Out:
# 35.25

# %%
dfsouth
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40

# %%
dfnorth
# Out:
#       City  Temp  Humid
# 0    Delhi    34     40
# 1   Jaipur    38     43
# 2   Bhopal    33     42
# 3  Lucknow    36     40

# %%
pd.concat([dfsouth, dfnorth], axis = 1)
# Out:
#         City  Temp  Humid     City  Temp  Humid
# 0      Vizag    34     40    Delhi    34     40
# 1    Chennai    38     43   Jaipur    38     43
# 2  Hyderabad    33     42   Bhopal    33     42
# 3  Bangalore    36     40  Lucknow    36     40

# %%
d3 = {
    
    "City" :["Vizag","Chennai", "Hyderabad","Bangalore"],
    "Temp" : [34,38,33,36],

    
    
}



d4 = {
    
    "City" :["Vizag","Chennai", "Hyderabad","Bangalore"],
    "Humid" : [40,43,42,40]
    
    
}

# %%
d3
# Out:
# {'City': ['Vizag', 'Chennai', 'Hyderabad', 'Bangalore'],
#  'Temp': [34, 38, 33, 36]}

# %%
d4
# Out:
# {'City': ['Vizag', 'Chennai', 'Hyderabad', 'Bangalore'],
#  'Humid': [40, 43, 42, 40]}

# %%
dfd3 = pd.DataFrame(d3)

# %%
dfd4 = pd.DataFrame(d4)

# %%
dfd3
# Out:
#         City  Temp
# 0      Vizag    34
# 1    Chennai    38
# 2  Hyderabad    33
# 3  Bangalore    36

# %%
dfd4
# Out:
#         City  Humid
# 0      Vizag     40
# 1    Chennai     43
# 2  Hyderabad     42
# 3  Bangalore     40

# %%
pd.concat([dfd3, dfd4], axis = 1)
# Out:
#         City  Temp       City  Humid
# 0      Vizag    34      Vizag     40
# 1    Chennai    38    Chennai     43
# 2  Hyderabad    33  Hyderabad     42
# 3  Bangalore    36  Bangalore     40

# %%
dfd3
# Out:
#         City  Temp
# 0      Vizag    34
# 1    Chennai    38
# 2  Hyderabad    33
# 3  Bangalore    36

# %%
dfd4
# Out:
#         City  Humid
# 0      Vizag     40
# 1    Chennai     43
# 2  Hyderabad     42
# 3  Bangalore     40

# %%
dfd31 = dfd3.set_index("City")

# %%
dfd31
# Out:
#            Temp
# City
# Vizag        34
# Chennai      38
# Hyderabad    33
# Bangalore    36

# %%
dfd4
# Out:
#         City  Humid
# 0      Vizag     40
# 1    Chennai     43
# 2  Hyderabad     42
# 3  Bangalore     40

# %%
dfd41 = dfd4.set_index("City")

# %%
dfd41
# Out:
#            Humid
# City
# Vizag         40
# Chennai       43
# Hyderabad     42
# Bangalore     40

# %%
dfresult = pd.concat([dfd31, dfd41], axis = 1)

# %%
dfresult
# Out:
#            Temp  Humid
# City
# Vizag        34     40
# Chennai      38     43
# Hyderabad    33     42
# Bangalore    36     40

# %%
dfresult = dfresult.reset_index()

# %%
display(dfd3, dfd4, dfresult)
# Out:
#         City  Temp
# 0      Vizag    34
# 1    Chennai    38
# 2  Hyderabad    33
# 3  Bangalore    36
#         City  Humid
# 0      Vizag     40
# 1    Chennai     43
# 2  Hyderabad     42
# 3  Bangalore     40
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40

# %%
d5 = {
    
    "City" :["Vizag","Chennai", "Hyderabad","Bangalore"],
    "Temp" : [34,38,33,36],

    
    
}



d6 = {
    
    "City" :["Vizag","Chennai"],
    "Humid" : [40,43]
    
    
}

dfd5 = pd.DataFrame(d5)
dfd6 = pd.DataFrame(d6)

# %%
display(dfd5, dfd6)
# Out:
#         City  Temp
# 0      Vizag    34
# 1    Chennai    38
# 2  Hyderabad    33
# 3  Bangalore    36
#       City  Humid
# 0    Vizag     40
# 1  Chennai     43

# %%
pd.concat([dfd5, dfd6])
# Out:
#         City  Temp  Humid
# 0      Vizag  34.0    NaN
# 1    Chennai  38.0    NaN
# 2  Hyderabad  33.0    NaN
# 3  Bangalore  36.0    NaN
# 0      Vizag   NaN   40.0
# 1    Chennai   NaN   43.0

# %%
pd.concat([dfd5, dfd6],axis = 1)
# Out:
#         City  Temp     City  Humid
# 0      Vizag    34    Vizag   40.0
# 1    Chennai    38  Chennai   43.0
# 2  Hyderabad    33      NaN    NaN
# 3  Bangalore    36      NaN    NaN

# %%
pd.concat([dfd5, dfd6],axis = 1, join = "outer")
# Out:
#         City  Temp     City  Humid
# 0      Vizag    34    Vizag   40.0
# 1    Chennai    38  Chennai   43.0
# 2  Hyderabad    33      NaN    NaN
# 3  Bangalore    36      NaN    NaN

# %%
pd.concat([dfd5, dfd6],axis = 1, join = "inner")
# Out:
#       City  Temp     City  Humid
# 0    Vizag    34    Vizag     40
# 1  Chennai    38  Chennai     43

# %% [markdown]
# dfsouth

# %%
dfsouth
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40

# %%
dfnorth
# Out:
#       City  Temp  Humid
# 0    Delhi    34     40
# 1   Jaipur    38     43
# 2   Bhopal    33     42
# 3  Lucknow    36     40

# %%
pd.concat([dfsouth, dfnorth], keys = ["South", "North"])
# Out:
#               City  Temp  Humid
# South 0      Vizag    34     40
#       1    Chennai    38     43
#       2  Hyderabad    33     42
#       3  Bangalore    36     40
# North 0      Delhi    34     40
#       1     Jaipur    38     43
#       2     Bhopal    33     42
#       3    Lucknow    36     40

# %%
dfind10 = pd.concat([dfsouth, dfnorth], keys = ["South", "North"], axis = 1)

# %%
dfind10
# Out:
#        South               North
#         City Temp Humid     City Temp Humid
# 0      Vizag   34    40    Delhi   34    40
# 1    Chennai   38    43   Jaipur   38    43
# 2  Hyderabad   33    42   Bhopal   33    42
# 3  Bangalore   36    40  Lucknow   36    40

# %%
dfind10["South"]
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40

# %%
dfind10["South"]["Temp"]
# Out:
# 0    34
# 1    38
# 2    33
# 3    36
# Name: Temp, dtype: int64

# %%
dfind10["South"]["Temp"].mean()
# Out:
# 35.25

# %% [markdown]
# ### PANDAS MERGE

# %%
dfd3
# Out:
#         City  Temp
# 0      Vizag    34
# 1    Chennai    38
# 2  Hyderabad    33
# 3  Bangalore    36

# %%
dfd4
# Out:
#         City  Humid
# 0      Vizag     40
# 1    Chennai     43
# 2  Hyderabad     42
# 3  Bangalore     40

# %%
pd.concat([dfd3, dfd4], axis = 1)
# Out:
#         City  Temp       City  Humid
# 0      Vizag    34      Vizag     40
# 1    Chennai    38    Chennai     43
# 2  Hyderabad    33  Hyderabad     42
# 3  Bangalore    36  Bangalore     40

# %%
pd.merge(dfd3, dfd4, on = ["City"])
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40

# %%
dfd3["State"] = ["AP","TN","TS","KA"]

# %%
dfd3
# Out:
#         City  Temp State
# 0      Vizag    34    AP
# 1    Chennai    38    TN
# 2  Hyderabad    33    TS
# 3  Bangalore    36    KA

# %%
dfd3 = dfd3[["City", "State","Temp"]]

# %%
dfd3
# Out:
#         City State  Temp
# 0      Vizag    AP    34
# 1    Chennai    TN    38
# 2  Hyderabad    TS    33
# 3  Bangalore    KA    36

# %%
dfd4["State"] =  ["AP","TN","TS","KA"]

# %%
dfd4
# Out:
#         City  Humid State
# 0      Vizag     40    AP
# 1    Chennai     43    TN
# 2  Hyderabad     42    TS
# 3  Bangalore     40    KA

# %%
dfd4 = dfd4[["City", "State","Humid"]]

# %%
dfd4
# Out:
#         City State  Humid
# 0      Vizag    AP     40
# 1    Chennai    TN     43
# 2  Hyderabad    TS     42
# 3  Bangalore    KA     40

# %%
dfd3
# Out:
#         City State  Temp
# 0      Vizag    AP    34
# 1    Chennai    TN    38
# 2  Hyderabad    TS    33
# 3  Bangalore    KA    36

# %%
dfd4
# Out:
#         City State  Humid
# 0      Vizag    AP     40
# 1    Chennai    TN     43
# 2  Hyderabad    TS     42
# 3  Bangalore    KA     40

# %%
df3 = dfd3.drop("State", axis = 1)

# %%
df4 = dfd4.drop("State", axis = 1)

# %%
df3
# Out:
#         City  Temp
# 0      Vizag    34
# 1    Chennai    38
# 2  Hyderabad    33
# 3  Bangalore    36

# %%
df4
# Out:
#         City  Humid
# 0      Vizag     40
# 1    Chennai     43
# 2  Hyderabad     42
# 3  Bangalore     40

# %%
pd.merge(df3, df4, on = "City")
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40

# %%
pd.merge(df3, df4)
# Out:
#         City  Temp  Humid
# 0      Vizag    34     40
# 1    Chennai    38     43
# 2  Hyderabad    33     42
# 3  Bangalore    36     40

# %%
dfd3
# Out:
#         City State  Temp
# 0      Vizag    AP    34
# 1    Chennai    TN    38
# 2  Hyderabad    TS    33
# 3  Bangalore    KA    36

# %%
dfd4
# Out:
#         City State  Humid
# 0      Vizag    AP     40
# 1    Chennai    TN     43
# 2  Hyderabad    TS     42
# 3  Bangalore    KA     40

# %%
pd.merge(dfd3, dfd4)
# Out:
#         City State  Temp  Humid
# 0      Vizag    AP    34     40
# 1    Chennai    TN    38     43
# 2  Hyderabad    TS    33     42
# 3  Bangalore    KA    36     40

# %%
pd.merge(dfd3, dfd4, on = ["City","State"])
# Out:
#         City State  Temp  Humid
# 0      Vizag    AP    34     40
# 1    Chennai    TN    38     43
# 2  Hyderabad    TS    33     42
# 3  Bangalore    KA    36     40

# %%
pd.merge(dfd3, dfd4, on = ["City"])
# Out:
#         City State_x  Temp State_y  Humid
# 0      Vizag      AP    34      AP     40
# 1    Chennai      TN    38      TN     43
# 2  Hyderabad      TS    33      TS     42
# 3  Bangalore      KA    36      KA     40

# %%
pd.merge(dfd3, dfd4, on = ["City"], suffixes= ["_USA", "_INDIA"])
# Out:
#         City State_USA  Temp State_INDIA  Humid
# 0      Vizag        AP    34          AP     40
# 1    Chennai        TN    38          TN     43
# 2  Hyderabad        TS    33          TS     42
# 3  Bangalore        KA    36          KA     40

# %%
pd.merge()
